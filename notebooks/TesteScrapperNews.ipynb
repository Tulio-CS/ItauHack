# %% [markdown]
# Scraper de headlines do Investing.com (PT-BR) por empresa.
# Lê um Excel (BaseRefAtivos.xlsx) com:
#   Empresa | Setor | Ticker BDR | Ticker Original (EUA) | Bolsa (EUA) | Link News
#
# Saída: Parquet com colunas:
#   id, datetime, source, headline, ticker, sector, country, url, language
#
# Destaques de debug:
# - logging com níveis, --verbose/--debug
# - --only para filtrar por ticker ou empresa
# - --max-pages (padrão 15) para smoke test
# - --save-html-debug salva HTML bruto de páginas em ./_html_debug
# - retries com backoff/jitter e tratamento de 429/5xx
# - checkpoint incremental (--resume): mescla com parquet existente e evita retrabalho

# %%
from __future__ import annotations
import re
import time
import uuid
import os
import random
import argparse
from pathlib import Path
from typing import Optional, List, Dict
from datetime import datetime, timedelta
from zoneinfo import ZoneInfo

import pandas as pd
import requests
from bs4 import BeautifulSoup
from dateutil import parser as du
from tqdm import tqdm
import logging

# ---------------- Config & Globals ----------------
SP_TZ = ZoneInfo("America/Sao_Paulo")

DEFAULT_EXCEL = "../data/BaseRefAtivos.xlsx"
DEFAULT_OUT = "../data/investing_news.parquet"
DEFAULT_MAX_PAGES = 1400  # <- limite padrão para facilitar debug rápido

HEADERS = {
    "User-Agent": (
        "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
        "AppleWebKit/537.36 (KHTML, like Gecko) "
        "Chrome/127.0.0.0 Safari/537.36"
    ),
    "Accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7",
    "Accept-Language": "pt-BR,pt;q=0.9,en-US;q=0.8,en;q=0.7",
    "Referer": "https://br.investing.com/", # Informa de onde você "veio"
    "DNT": "1", # Do Not Track
    "Upgrade-Insecure-Requests": "1",
    "Sec-Fetch-Dest": "document",
    "Sec-Fetch-Mode": "navigate",
}

SESSION = requests.Session()
SESSION.headers.update(HEADERS)

RELATIVE_REGEX = re.compile(
    r"(?P<num>\d+)\s*(?P<unit>min|mins|minutos|minuto|hora|horas|dia|dias)\s*atr[aá]s",
    flags=re.IGNORECASE,
)

# ---------------- Logging ----------------
def setup_logging(verbose: bool = False, debug: bool = False) -> None:
    level = logging.INFO
    if verbose or debug:
        level = logging.DEBUG
    logging.basicConfig(
        level=level,
        format="%(asctime)s | %(levelname)-7s | %(message)s",
        datefmt="%H:%M:%S",
    )

log = logging.getLogger(__name__)

# ---------------- Utils ----------------
def normalize_news_url(url: str) -> str:
    """Garante base ...-news e remove sufixo /<n> para paginar manualmente."""
    url = (url or "").strip()
    if not url:
        return url
    if url.endswith("-new"):
        url = url + "s"
    url = re.sub(r"/+$", "", url)
    m = re.search(r"/(\d+)$", url)
    if m:
        url = url[: - (len(m.group(0)))]
    return url

def page_url(url_base: str, page: int) -> str:
    return f"{url_base}/{page}"

def parse_datetime_from_time_tag(time_tag) -> Optional[datetime]:
    if time_tag is None:
        return None

    text = (time_tag.get_text() or "").strip().lower()
    m = RELATIVE_REGEX.search(text)
    if m:
        num = int(m.group("num"))
        unit = m.group("unit")
        now_sp = datetime.now(SP_TZ)

        if unit.startswith("min"):
            dt = now_sp - timedelta(minutes=num)
        elif unit.startswith("hora"):
            dt = now_sp - timedelta(hours=num)
        else:
            dt = now_sp - timedelta(days=num)
        return dt

    dt_attr = time_tag.get("datetime")
    if dt_attr:
        try:
            dt = du.parse(dt_attr)
            if dt.tzinfo is None:
                dt = dt.replace(tzinfo=SP_TZ)
            return dt.astimezone(SP_TZ)
        except Exception as e:
            log.debug(f"Falha parse datetime attr '{dt_attr}': {e}")

    # fallback: parse do texto absoluto, ex.: "12 de out. de 2025"
    try:
        dt = du.parse(text, dayfirst=True, fuzzy=True, languages=["pt"])
        if dt is not None:
            if dt.tzinfo is None:
                dt = dt.replace(tzinfo=SP_TZ)
            return dt.astimezone(SP_TZ)
    except Exception as e:
        log.debug(f"Falha parse texto de data '{text}': {e}")

    return None

def deduce_country_language_from_url(url: str) -> tuple[str, str]:
    if "br.investing.com" in url:
        return ("BR", "pt-BR")
    return ("", "")

def make_news_id(url: str, title: str) -> str:
    base = (url or "").strip() + "||" + (title or "").strip()
    return str(uuid.uuid5(uuid.NAMESPACE_URL, base))

def html_debug_dump(html: str, company: str, page: int, outdir: Path) -> None:
    outdir.mkdir(parents=True, exist_ok=True)
    fn = outdir / f"{safe_filename(company)}_p{page:04d}.html"
    try:
        fn.write_text(html, encoding="utf-8")
        log.debug(f"HTML salvo para debug: {fn}")
    except Exception as e:
        log.warning(f"Falha ao salvar HTML de debug: {e}")

def safe_filename(s: str) -> str:
    return re.sub(r"[^A-Za-z0-9._-]+", "_", s.strip())

# ---------------- HTTP com backoff ----------------
def fetch(url: str, max_retries: int = 5, timeout: int = 25) -> Optional[requests.Response]:
    for i in range(max_retries):
        try:
            r = SESSION.get(url, timeout=timeout)
            if r.status_code == 200:
                return r
            if r.status_code in (404, 410):
                log.info(f"HTTP {r.status_code} em {url} (provável fim).")
                return None
            if r.status_code in (429, 500, 502, 503, 504):
                wait = (1.5 * (i + 1)) + random.random()
                log.warning(f"HTTP {r.status_code} em {url}; retry em {wait:.1f}s")
                time.sleep(wait)
                continue
            log.warning(f"HTTP {r.status_code} em {url}; sem retry programado.")
            return None
        except requests.RequestException as e:
            wait = (1.2 * (i + 1)) + random.random()
            log.warning(f"Erro rede: {e}; retry em {wait:.1f}s")
            time.sleep(wait)
    log.error(f"Falhou após {max_retries} tentativas: {url}")
    return None

# ---------------- Parsing ----------------
def parse_news_items(html: str, ticker: str, sector: str) -> List[Dict]:
    soup = BeautifulSoup(html, "html.parser")
    ul = soup.find("ul", attrs={"data-test": "news-list"})
    if not ul:
        log.debug("Ul[data-test='news-list'] não encontrada — página pode ter mudado.")
        return []

    items: List[Dict] = []
    arts = ul.select("article[data-test='article-item']")
    if not arts:
        log.debug("Nenhum article[data-test='article-item'] encontrado nesta página.")
        return []

    for art in arts:
        a_title = art.select_one("a[data-test='article-title-link']")
        if not a_title:
            log.debug("a[data-test='article-title-link'] ausente em um article; pulando.")
            continue

        headline = (a_title.get_text() or "").strip()
        url = a_title.get("href") or ""
        if url.startswith("/"):
            url = "https://br.investing.com" + url

        a_provider = art.select_one("a[data-test='article-provider-link']")
        source = (a_provider.get_text().strip() if a_provider else "").strip()

        t = art.select_one("time[data-test='article-publish-date']")
        dt = parse_datetime_from_time_tag(t)

        country, language = deduce_country_language_from_url(url)
        _id = make_news_id(url, headline)

        items.append(
            {
                "id": _id,
                "datetime": dt.isoformat() if dt else None,
                "source": source,
                "headline": headline,
                "ticker": ticker,
                "sector": sector,
                "country": country,
                "url": url,
                "language": language,
            }
        )
    return items

def guess_last_page(html: str) -> Optional[int]:
    soup = BeautifulSoup(html, "html.parser")
    pag_links = soup.select("div.flex.items-center.gap-2 a")
    nums = []
    for a in pag_links:
        txt = (a.get_text() or "").strip()
        if txt.isdigit():
            nums.append(int(txt))
    return max(nums) if nums else None

# ---------------- Scraper por empresa ----------------
def scrape_company(
    link_news: str,
    ticker_orig: str,
    sector: str,
    company_label: str,
    polite_sleep: float = 0.7,
    max_pages: Optional[int] = DEFAULT_MAX_PAGES,
    save_html_debug: bool = False,
    html_debug_dir: Path = Path("./_html_debug"),
) -> List[Dict]:
    url_base = normalize_news_url(link_news)
    if not url_base:
        log.warning(f"[{company_label}] Link News vazio.")
        return []

    first_url = page_url(url_base, 1)
    r1 = fetch(first_url)
    if not r1:
        log.warning(f"[{company_label}] Não foi possível carregar a página 1: {first_url}")
        return []

    if save_html_debug:
        html_debug_dump(r1.text, company_label, 1, html_debug_dir)

    items = parse_news_items(r1.text, ticker_orig, sector)
    log.info(f"[{company_label}] p1: {len(items)} items.")

    last_page = guess_last_page(r1.text)
    if last_page is None:
        # fallback: iterar enquanto vier notícia (parando após X vazias seguidas)
        page = 2
        empty_streak = 0
        while True:
            if max_pages and page > max_pages:
                log.info(f"[{company_label}] max_pages atingido ({max_pages}).")
                break

            url = page_url(url_base, page)
            time.sleep(polite_sleep)
            r = fetch(url)
            if not r:
                empty_streak += 1
                log.debug(f"[{company_label}] página {page} falhou ({empty_streak} vazias).")
                if empty_streak >= 3:
                    log.info(f"[{company_label}] 3 páginas vazias seguidas; encerrando.")
                    break
                page += 1
                continue

            if save_html_debug:
                html_debug_dump(r.text, company_label, page, html_debug_dir)

            chunk = parse_news_items(r.text, ticker_orig, sector)
            log.info(f"[{company_label}] p{page}: {len(chunk)} items.")
            if not chunk:
                empty_streak += 1
                if empty_streak >= 3:
                    log.info(f"[{company_label}] 3 páginas sem itens; encerrando.")
                    break
            else:
                items.extend(chunk)
                empty_streak = 0
            page += 1
    else:
        total_pages = last_page
        if max_pages:
            total_pages = min(total_pages, max_pages)
        for page in range(2, total_pages + 1):
            url = page_url(url_base, page)
            time.sleep(polite_sleep)
            r = fetch(url)
            if not r:
                log.debug(f"[{company_label}] Falha ao carregar p{page}.")
                continue

            if save_html_debug:
                html_debug_dump(r.text, company_label, page, html_debug_dir)

            chunk = parse_news_items(r.text, ticker_orig, sector)
            log.info(f"[{company_label}] p{page}: {len(chunk)} items.")
            items.extend(chunk)

    return items

# ---------------- Execução principal ----------------
def read_excel(excel_path: Path) -> pd.DataFrame:
    df = pd.read_excel(excel_path)
    expected_cols = {
        "Empresa", "Setor", "Ticker BDR", "Ticker Original (EUA)", "Bolsa (EUA)", "Link News",
    }
    missing = expected_cols - set(df.columns)
    if missing:
        raise ValueError(f"Colunas faltantes no Excel: {sorted(missing)}")
    return df

def merge_incremental(df_new: pd.DataFrame, out_parquet: Path) -> pd.DataFrame:
    if out_parquet.exists():
        df_old = pd.read_parquet(out_parquet)
        df_all = pd.concat([df_old, df_new], ignore_index=True)
        df_all = df_all.drop_duplicates(subset=["id"]).reset_index(drop=True)
        return df_all
    return df_new

def sort_by_datetime(df: pd.DataFrame) -> pd.DataFrame:
    def _safe_parse_iso(x):
        try:
            return du.parse(x)
        except Exception:
            return None
    if "datetime" in df.columns:
        df["_dt_sort"] = df["datetime"].map(_safe_parse_iso)
        df = df.sort_values("_dt_sort", ascending=False).drop(columns=["_dt_sort"])
    return df

def run(
    excel: Path,
    out_parquet: Path,
    only: Optional[str],
    max_pages: Optional[int],
    resume: bool,
    save_html_debug: bool,
    workers: int,
):
    df_ref = read_excel(excel)

    # filtro --only por ticker original OU empresa (case-insensitive, contém)
    if only:
        mask = (
            df_ref["Ticker Original (EUA)"].astype(str).str.contains(only, case=False, na=False) |
            df_ref["Empresa"].astype(str).str.contains(only, case=False, na=False)
        )
        df_ref = df_ref[mask].copy()
        log.info(f"Filtrando --only '{only}'. {len(df_ref)} linha(s) no Excel após filtro.")

    all_rows: List[Dict] = []

    # processamento sequencial (simples e mais debugável)
    for _, row in tqdm(df_ref.iterrows(), total=len(df_ref), desc="Empresas"):
        empresa = str(row["Empresa"]).strip()
        setor = str(row["Setor"]).strip()
        ticker_orig = str(row["Ticker Original (EUA)"]).strip()
        link_news = str(row["Link News"]).strip()

        if not link_news or link_news.lower() == "nan":
            log.warning(f"[{empresa}] Link News vazio; pulando.")
            continue

        label = ticker_orig or empresa
        items = scrape_company(
            link_news=link_news,
            ticker_orig=ticker_orig or empresa,
            sector=setor,
            company_label=label,
            polite_sleep=0.7,
            max_pages=max_pages if max_pages is not None else DEFAULT_MAX_PAGES,
            save_html_debug=save_html_debug,
        )
        if not items:
            log.info(f"[{label}] Nenhuma notícia encontrada.")
            continue

        df_company = pd.DataFrame(items).drop_duplicates(subset=["id"]).reset_index(drop=True)

        if resume and out_parquet.exists():
            df_merged = merge_incremental(df_company, out_parquet)
            df_merged = sort_by_datetime(df_merged)
            df_merged.to_parquet(out_parquet, index=False)
            log.info(f"[{label}] Merge incremental -> {len(df_merged)} linhas em {out_parquet}")
        else:
            all_rows.extend(df_company.to_dict("records"))

    # flush final quando não está em modo resume
    if not resume and all_rows:
        df = pd.DataFrame(all_rows).drop_duplicates(subset=["id"]).reset_index(drop=True)
        df = sort_by_datetime(df)
        df.to_parquet(out_parquet, index=False)
        log.info(f"Salvo {len(df):,} notícias em {out_parquet}")
    elif not all_rows and not out_parquet.exists():
        log.warning("Nenhuma notícia encontrada e arquivo de saída ainda não existe.")

# ---------------- CLI ----------------
def parse_args():
    p = argparse.ArgumentParser(description="Scraper de notícias do Investing.com (PT-BR)")
    p.add_argument("--excel", default=DEFAULT_EXCEL, help="Caminho do Excel de referência")
    p.add_argument("--out", default=DEFAULT_OUT, help="Arquivo Parquet de saída")
    p.add_argument("--only", default=None, help="Filtra por Ticker Original (EUA) ou Empresa (contém, case-insensitive)")
    p.add_argument("--max-pages", type=int, default=DEFAULT_MAX_PAGES, help="Limite máx. de páginas por ativo (padrão 15)")
    p.add_argument("--resume", action="store_true", help="Mescla incremental com parquet existente (checkpoint por empresa)")
    p.add_argument("--save-html-debug", action="store_true", help="Salva HTML das páginas em ./_html_debug")
    p.add_argument("--workers", type=int, default=1, help="(reservado) Nº de workers em paralelo (mantido sequencial por debug)")
    p.add_argument("--verbose", action="store_true", help="Logs detalhados (DEBUG)")
    p.add_argument("--debug", action="store_true", help="Equivalente a --verbose")

    # tolerar args estranhos do Jupyter/VSCode:
    args, _unknown = p.parse_known_args()
    return args

def main():
    import sys
    # sanitiza argv quando rodar dentro de notebooks com ipykernel
    if any("ipykernel" in x for x in sys.argv):
        # mantém os próprios args reconhecidos, graças ao parse_known_args acima
        pass

    args = parse_args()
    setup_logging(verbose=args.verbose or args.debug, debug=args.debug)

    excel = Path(args.excel)
    out_parquet = Path(args.out)

    log.info(f"Excel: {excel.resolve()}")
    log.info(f"Saída: {out_parquet.resolve()}")
    if args.only:
        log.info(f"Filtro --only: {args.only}")
    log.info(f"Limite de páginas: {args.max_pages}")
    if args.resume:
        log.info("Modo incremental: ON")
    if args.save_html_debug:
        log.info("Salvar HTML debug: ON")

    try:
        run(
            excel=excel,
            out_parquet=out_parquet,
            only=args.only,
            max_pages=args.max_pages,
            resume=args.resume,
            save_html_debug=args.save_html_debug,
            workers=args.workers,
        )
    except Exception as e:
        log.exception(f"Falha fatal: {e}")

if __name__ == "__main__":
    main()
# Out:
# 00:50:54 | INFO    | Excel: /Users/emanuelgandra/Desktop/Projetos /TesteQuant/QuantumSpreadHunters---Quantamental/data/BaseRefAtivos.xlsx
# 00:50:54 | INFO    | Saída: /Users/emanuelgandra/Desktop/Projetos /TesteQuant/QuantumSpreadHunters---Quantamental/data/investing_news.parquet
# 00:50:54 | INFO    | Limite de páginas: 1400
# Empresas:   0%|          | 0/43 [00:00<?, ?it/s]00:51:45 | INFO    | [AAPL] p1: 10 items.
# 00:51:47 | INFO    | [AAPL] p2: 10 items.
# 00:51:49 | INFO    | [AAPL] p3: 10 items.
# 00:51:51 | INFO    | [AAPL] p4: 10 items.
# 00:51:53 | INFO    | [AAPL] p5: 10 items.
# 00:51:55 | INFO    | [AAPL] p6: 10 items.
# 00:51:56 | INFO    | [AAPL] p7: 10 items.
# 00:51:58 | INFO    | [AAPL] p8: 10 items.
# 00:52:00 | INFO    | [AAPL] p9: 10 items.
# 00:52:02 | INFO    | [AAPL] p10: 10 items.
# 00:52:04 | INFO    | [AAPL] p11: 10 items.
# 00:52:06 | INFO    | [AAPL] p12: 10 items.
# 00:52:08 | INFO    | [AAPL] p13: 10 items.
# 00:52:10 | INFO    | [AAPL] p14: 10 items.
# 00:52:12 | INFO    | [AAPL] p15: 10 items.
# 00:52:14 | INFO    | [AAPL] p16: 10 items.
# 00:52:16 | INFO    | [AAPL] p17: 10 items.
# 00:52:18 | INFO    | [AAPL] p18: 10 items.
# 00:52:20 | INFO    | [AAPL] p19: 10 items.
# 00:52:22 | INFO    | [AAPL] p20: 10 items.
# 00:52:24 | INFO    | [AAPL] p21: 10 items.
# 00:52:26 | INFO    | [AAPL] p22: 10 items.
# 00:52:28 | INFO    | [AAPL] p23: 10 items.
# 00:52:30 | INFO    | [AAPL] p24: 10 items.
# 00:52:33 | INFO    | [AAPL] p25: 10 items.
# 00:52:35 | INFO    | [AAPL] p26: 10 items.
# 00:52:37 | INFO    | [AAPL] p27: 10 items.
# 00:52:39 | INFO    | [AAPL] p28: 10 items.
# 00:52:41 | INFO    | [AAPL] p29: 10 items.
# 00:52:43 | INFO    | [AAPL] p30: 10 items.
# 00:52:45 | INFO    | [AAPL] p31: 10 items.
# 00:52:46 | INFO    | [AAPL] p32: 10 items.
# 00:52:48 | INFO    | [AAPL] p33: 10 items.
# 00:52:50 | INFO    | [AAPL] p34: 10 items.
# 00:52:52 | INFO    | [AAPL] p35: 10 items.
# 00:52:54 | INFO    | [AAPL] p36: 10 items.
# 00:52:56 | INFO    | [AAPL] p37: 10 items.
# 00:52:57 | INFO    | [AAPL] p38: 10 items.
# 00:52:59 | INFO    | [AAPL] p39: 10 items.
# 00:53:01 | INFO    | [AAPL] p40: 10 items.
# 00:53:03 | INFO    | [AAPL] p41: 10 items.
# 00:53:05 | INFO    | [AAPL] p42: 10 items.
# 00:53:07 | INFO    | [AAPL] p43: 10 items.
# 00:53:09 | INFO    | [AAPL] p44: 10 items.
# 00:53:11 | INFO    | [AAPL] p45: 10 items.
# 00:53:13 | INFO    | [AAPL] p46: 10 items.
# 00:53:15 | INFO    | [AAPL] p47: 10 items.
# 00:53:17 | INFO    | [AAPL] p48: 10 items.
# 00:53:18 | INFO    | [AAPL] p49: 10 items.
# 00:53:20 | INFO    | [AAPL] p50: 10 items.
# 00:53:22 | INFO    | [AAPL] p51: 10 items.
# 00:53:25 | INFO    | [AAPL] p52: 10 items.
# 00:53:27 | INFO    | [AAPL] p53: 10 items.
# 00:53:29 | INFO    | [AAPL] p54: 10 items.
# 00:53:31 | INFO    | [AAPL] p55: 10 items.
# 00:53:34 | INFO    | [AAPL] p56: 10 items.
# 00:53:36 | INFO    | [AAPL] p57: 10 items.
# 00:53:37 | INFO    | [AAPL] p58: 10 items.
# 00:53:39 | INFO    | [AAPL] p59: 10 items.
# 00:53:41 | INFO    | [AAPL] p60: 10 items.
# 00:53:43 | INFO    | [AAPL] p61: 10 items.
# 00:53:45 | INFO    | [AAPL] p62: 10 items.
# 00:53:47 | INFO    | [AAPL] p63: 10 items.
# 00:53:49 | INFO    | [AAPL] p64: 10 items.
# 00:53:51 | INFO    | [AAPL] p65: 10 items.
# 00:53:52 | INFO    | [AAPL] p66: 10 items.
# 00:53:54 | INFO    | [AAPL] p67: 10 items.
# 00:53:56 | INFO    | [AAPL] p68: 10 items.
# 00:53:58 | INFO    | [AAPL] p69: 10 items.
# 00:54:00 | INFO    | [AAPL] p70: 10 items.
# 00:54:02 | INFO    | [AAPL] p71: 10 items.
# 00:54:04 | INFO    | [AAPL] p72: 10 items.
# 00:54:06 | INFO    | [AAPL] p73: 10 items.
# 00:54:08 | INFO    | [AAPL] p74: 10 items.
# 00:54:10 | INFO    | [AAPL] p75: 10 items.
# 00:54:12 | INFO    | [AAPL] p76: 10 items.
# 00:54:13 | INFO    | [AAPL] p77: 10 items.
# 00:54:15 | INFO    | [AAPL] p78: 10 items.
# 00:54:17 | INFO    | [AAPL] p79: 10 items.
# 00:54:19 | INFO    | [AAPL] p80: 10 items.
# 00:54:21 | INFO    | [AAPL] p81: 10 items.
# 00:54:23 | INFO    | [AAPL] p82: 10 items.
# 00:54:25 | INFO    | [AAPL] p83: 10 items.
# 00:54:27 | INFO    | [AAPL] p84: 10 items.
# 00:54:29 | INFO    | [AAPL] p85: 10 items.
# 00:54:32 | INFO    | [AAPL] p86: 10 items.
# 00:54:34 | INFO    | [AAPL] p87: 10 items.
# 00:54:35 | INFO    | [AAPL] p88: 10 items.
# 00:54:38 | INFO    | [AAPL] p89: 10 items.
# 00:54:40 | INFO    | [AAPL] p90: 10 items.
# 00:54:42 | INFO    | [AAPL] p91: 10 items.
# 00:54:44 | INFO    | [AAPL] p92: 10 items.
# 00:54:46 | INFO    | [AAPL] p93: 10 items.
# 00:54:48 | INFO    | [AAPL] p94: 10 items.
# 00:54:50 | INFO    | [AAPL] p95: 10 items.
# 00:54:53 | INFO    | [AAPL] p96: 10 items.
# 00:54:55 | INFO    | [AAPL] p97: 10 items.
# 00:54:57 | INFO    | [AAPL] p98: 10 items.
# 00:54:59 | INFO    | [AAPL] p99: 10 items.
# 00:55:01 | INFO    | [AAPL] p100: 10 items.
# 00:55:09 | INFO    | [AAPL] p101: 10 items.
# 00:55:11 | INFO    | [AAPL] p102: 10 items.
# 00:55:14 | INFO    | [AAPL] p103: 10 items.
# 00:55:17 | INFO    | [AAPL] p104: 10 items.
# 00:55:19 | INFO    | [AAPL] p105: 10 items.
# 00:55:21 | INFO    | [AAPL] p106: 10 items.
# 00:55:23 | INFO    | [AAPL] p107: 10 items.
# 00:55:25 | INFO    | [AAPL] p108: 10 items.
# 00:55:27 | INFO    | [AAPL] p109: 10 items.
# 00:55:29 | INFO    | [AAPL] p110: 10 items.
# 00:55:31 | INFO    | [AAPL] p111: 10 items.
# 00:55:33 | INFO    | [AAPL] p112: 10 items.
# 00:55:37 | INFO    | [AAPL] p113: 10 items.
# 00:55:39 | INFO    | [AAPL] p114: 10 items.
# 00:55:41 | INFO    | [AAPL] p115: 10 items.
# 00:55:43 | INFO    | [AAPL] p116: 10 items.
# 00:55:45 | INFO    | [AAPL] p117: 10 items.
# 00:55:48 | INFO    | [AAPL] p118: 10 items.
# 00:55:50 | INFO    | [AAPL] p119: 10 items.
# 00:55:52 | INFO    | [AAPL] p120: 10 items.
# 00:55:54 | INFO    | [AAPL] p121: 10 items.
# 00:55:56 | INFO    | [AAPL] p122: 10 items.
# 00:56:02 | INFO    | [AAPL] p123: 10 items.
# 00:56:04 | INFO    | [AAPL] p124: 10 items.
# 00:56:06 | INFO    | [AAPL] p125: 10 items.
# 00:56:07 | INFO    | [AAPL] p126: 10 items.
# 00:56:09 | INFO    | [AAPL] p127: 10 items.
# 00:56:12 | INFO    | [AAPL] p128: 10 items.
# 00:56:14 | INFO    | [AAPL] p129: 10 items.
# 00:56:15 | WARNING | HTTP 503 em https://br.investing.com/equities/apple-computer-inc-news/130; retry em 2.0s
# 00:56:18 | INFO    | [AAPL] p130: 10 items.
# 00:56:20 | INFO    | [AAPL] p131: 10 items.
# 00:56:22 | INFO    | [AAPL] p132: 10 items.
# 00:56:24 | INFO    | [AAPL] p133: 10 items.
# 00:56:27 | INFO    | [AAPL] p134: 10 items.
# 00:56:29 | INFO    | [AAPL] p135: 10 items.
# 00:56:31 | INFO    | [AAPL] p136: 10 items.
# 00:56:33 | INFO    | [AAPL] p137: 10 items.
# 00:56:36 | INFO    | [AAPL] p138: 10 items.
# 00:56:37 | INFO    | [AAPL] p139: 10 items.
# 00:56:40 | INFO    | [AAPL] p140: 10 items.
# 00:56:42 | INFO    | [AAPL] p141: 10 items.
# 00:56:43 | INFO    | [AAPL] p142: 10 items.
# 00:56:45 | INFO    | [AAPL] p143: 10 items.
# 00:56:47 | INFO    | [AAPL] p144: 10 items.
# 00:56:49 | INFO    | [AAPL] p145: 10 items.
# 00:56:51 | INFO    | [AAPL] p146: 10 items.
# 00:56:53 | INFO    | [AAPL] p147: 10 items.
# 00:56:55 | INFO    | [AAPL] p148: 10 items.
# 00:56:57 | INFO    | [AAPL] p149: 10 items.
# 00:56:59 | INFO    | [AAPL] p150: 10 items.
# 00:57:01 | INFO    | [AAPL] p151: 10 items.
# 00:57:03 | INFO    | [AAPL] p152: 10 items.
# 00:57:05 | INFO    | [AAPL] p153: 10 items.
# 00:57:07 | INFO    | [AAPL] p154: 10 items.
# 00:57:09 | INFO    | [AAPL] p155: 10 items.
# 00:57:11 | INFO    | [AAPL] p156: 10 items.
# 00:57:13 | INFO    | [AAPL] p157: 10 items.
# 00:57:15 | INFO    | [AAPL] p158: 10 items.
# 00:57:17 | INFO    | [AAPL] p159: 10 items.
# 00:57:19 | INFO    | [AAPL] p160: 10 items.
# 00:57:20 | INFO    | [AAPL] p161: 10 items.
# 00:57:22 | INFO    | [AAPL] p162: 10 items.
# 00:57:24 | INFO    | [AAPL] p163: 10 items.
# 00:57:27 | INFO    | [AAPL] p164: 10 items.
# 00:57:29 | INFO    | [AAPL] p165: 10 items.
# 00:57:31 | INFO    | [AAPL] p166: 10 items.
# 00:57:35 | INFO    | [AAPL] p167: 10 items.
# 00:57:39 | INFO    | [AAPL] p168: 10 items.
# 00:57:41 | INFO    | [AAPL] p169: 10 items.
# 00:57:43 | INFO    | [AAPL] p170: 10 items.
# 00:57:44 | INFO    | [AAPL] p171: 10 items.
# 00:57:46 | INFO    | [AAPL] p172: 10 items.
# 00:57:48 | INFO    | [AAPL] p173: 10 items.
# 00:57:50 | INFO    | [AAPL] p174: 10 items.
# 00:57:52 | INFO    | [AAPL] p175: 10 items.
# 00:57:54 | INFO    | [AAPL] p176: 10 items.
# 00:57:56 | INFO    | [AAPL] p177: 10 items.
# 00:57:58 | INFO    | [AAPL] p178: 10 items.
# 00:58:01 | INFO    | [AAPL] p179: 10 items.
# 00:58:02 | INFO    | [AAPL] p180: 10 items.
# 00:58:04 | INFO    | [AAPL] p181: 10 items.
# 00:58:06 | INFO    | [AAPL] p182: 10 items.
# 00:58:08 | INFO    | [AAPL] p183: 10 items.
# 00:58:11 | INFO    | [AAPL] p184: 10 items.
# 00:58:13 | INFO    | [AAPL] p185: 10 items.
# 00:58:14 | INFO    | [AAPL] p186: 10 items.
# 00:58:16 | INFO    | [AAPL] p187: 10 items.
# 00:58:20 | INFO    | [AAPL] p188: 10 items.
# 00:58:22 | INFO    | [AAPL] p189: 10 items.
# 00:58:24 | INFO    | [AAPL] p190: 10 items.
# 00:58:26 | INFO    | [AAPL] p191: 10 items.
# 00:58:28 | INFO    | [AAPL] p192: 10 items.
# 00:58:32 | INFO    | [AAPL] p193: 10 items.
# 00:58:34 | INFO    | [AAPL] p194: 10 items.
# 00:58:35 | INFO    | [AAPL] p195: 10 items.
# 00:58:37 | INFO    | [AAPL] p196: 10 items.
# 00:58:42 | INFO    | [AAPL] p197: 10 items.
# 00:58:45 | INFO    | [AAPL] p198: 10 items.
# 00:58:47 | INFO    | [AAPL] p199: 10 items.
# 00:58:49 | INFO    | [AAPL] p200: 10 items.
# 00:58:51 | INFO    | [AAPL] p201: 10 items.
# 00:58:53 | INFO    | [AAPL] p202: 10 items.
# 00:58:57 | INFO    | [AAPL] p203: 10 items.
# 00:58:59 | INFO    | [AAPL] p204: 10 items.
# 00:59:02 | INFO    | [AAPL] p205: 10 items.
# 00:59:04 | INFO    | [AAPL] p206: 10 items.
# 00:59:06 | INFO    | [AAPL] p207: 10 items.
# 00:59:08 | INFO    | [AAPL] p208: 10 items.
# 00:59:10 | INFO    | [AAPL] p209: 10 items.
# 00:59:12 | INFO    | [AAPL] p210: 10 items.
# 00:59:14 | INFO    | [AAPL] p211: 10 items.
# 00:59:16 | INFO    | [AAPL] p212: 10 items.
# 00:59:20 | INFO    | [AAPL] p213: 10 items.
# 00:59:21 | INFO    | [AAPL] p214: 10 items.
# 00:59:23 | INFO    | [AAPL] p215: 7 items.
# 00:59:26 | INFO    | [AAPL] p216: 10 items.
# 00:59:28 | INFO    | [AAPL] p217: 10 items.
# 00:59:30 | INFO    | [AAPL] p218: 10 items.
# 00:59:32 | INFO    | [AAPL] p219: 10 items.
# 00:59:34 | INFO    | [AAPL] p220: 10 items.
# 00:59:36 | INFO    | [AAPL] p221: 10 items.
# 00:59:38 | INFO    | [AAPL] p222: 10 items.
# 00:59:40 | INFO    | [AAPL] p223: 10 items.
# 00:59:42 | INFO    | [AAPL] p224: 10 items.
# 00:59:45 | INFO    | [AAPL] p225: 10 items.
# 00:59:47 | INFO    | [AAPL] p226: 10 items.
# 00:59:49 | INFO    | [AAPL] p227: 10 items.
# 00:59:51 | INFO    | [AAPL] p228: 10 items.
# 00:59:53 | INFO    | [AAPL] p229: 10 items.
# 00:59:55 | INFO    | [AAPL] p230: 10 items.
# 00:59:57 | INFO    | [AAPL] p231: 10 items.
# 00:59:59 | INFO    | [AAPL] p232: 10 items.
# 01:00:01 | INFO    | [AAPL] p233: 10 items.
# 01:00:03 | INFO    | [AAPL] p234: 10 items.
# 01:00:05 | INFO    | [AAPL] p235: 10 items.
# 01:00:07 | INFO    | [AAPL] p236: 10 items.
# 01:00:09 | INFO    | [AAPL] p237: 10 items.
# 01:00:11 | INFO    | [AAPL] p238: 10 items.
# 01:00:13 | INFO    | [AAPL] p239: 10 items.
# 01:00:15 | INFO    | [AAPL] p240: 10 items.
# 01:00:17 | INFO    | [AAPL] p241: 10 items.
# 01:00:20 | INFO    | [AAPL] p242: 10 items.
# 01:00:22 | INFO    | [AAPL] p243: 10 items.
# 01:00:24 | INFO    | [AAPL] p244: 10 items.
# 01:00:25 | INFO    | [AAPL] p245: 10 items.
# 01:00:27 | INFO    | [AAPL] p246: 10 items.
# 01:00:29 | INFO    | [AAPL] p247: 10 items.
# 01:00:31 | INFO    | [AAPL] p248: 10 items.
# 01:00:33 | INFO    | [AAPL] p249: 10 items.
# 01:00:35 | INFO    | [AAPL] p250: 10 items.
# 01:00:37 | INFO    | [AAPL] p251: 10 items.
# 01:00:39 | INFO    | [AAPL] p252: 10 items.
# 01:00:41 | INFO    | [AAPL] p253: 10 items.
# 01:00:43 | INFO    | [AAPL] p254: 10 items.
# 01:00:45 | INFO    | [AAPL] p255: 10 items.
# 01:00:47 | INFO    | [AAPL] p256: 10 items.
# 01:00:48 | INFO    | [AAPL] p257: 10 items.
# 01:00:50 | INFO    | [AAPL] p258: 10 items.
# 01:00:52 | INFO    | [AAPL] p259: 10 items.
# 01:00:54 | INFO    | [AAPL] p260: 10 items.
# 01:00:56 | INFO    | [AAPL] p261: 10 items.
# 01:00:58 | INFO    | [AAPL] p262: 10 items.
# 01:01:00 | INFO    | [AAPL] p263: 10 items.
# 01:01:02 | INFO    | [AAPL] p264: 10 items.
# 01:01:04 | INFO    | [AAPL] p265: 10 items.
# 01:01:06 | INFO    | [AAPL] p266: 10 items.
# 01:01:07 | INFO    | [AAPL] p267: 10 items.
# 01:01:09 | INFO    | [AAPL] p268: 10 items.
# 01:01:11 | INFO    | [AAPL] p269: 10 items.
# 01:01:13 | INFO    | [AAPL] p270: 10 items.
# 01:01:15 | INFO    | [AAPL] p271: 10 items.
# 01:01:18 | INFO    | [AAPL] p272: 10 items.
# 01:01:19 | INFO    | [AAPL] p273: 10 items.
# 01:01:22 | INFO    | [AAPL] p274: 10 items.
# 01:01:24 | INFO    | [AAPL] p275: 10 items.
# 01:01:27 | INFO    | [AAPL] p276: 10 items.
# 01:01:30 | INFO    | [AAPL] p277: 10 items.
# 01:01:32 | INFO    | [AAPL] p278: 10 items.
# 01:01:34 | INFO    | [AAPL] p279: 10 items.
# 01:01:36 | INFO    | [AAPL] p280: 10 items.
# 01:01:38 | INFO    | [AAPL] p281: 10 items.
# 01:01:40 | INFO    | [AAPL] p282: 10 items.
# 01:01:43 | INFO    | [AAPL] p283: 10 items.
# 01:01:45 | INFO    | [AAPL] p284: 10 items.
# 01:01:47 | INFO    | [AAPL] p285: 10 items.
# 01:01:48 | INFO    | [AAPL] p286: 10 items.
# 01:01:50 | INFO    | [AAPL] p287: 10 items.
# 01:01:53 | INFO    | [AAPL] p288: 10 items.
# 01:01:55 | INFO    | [AAPL] p289: 10 items.
# 01:01:57 | INFO    | [AAPL] p290: 10 items.
# 01:01:59 | INFO    | [AAPL] p291: 10 items.
# 01:02:01 | INFO    | [AAPL] p292: 5 items.
# 01:02:03 | INFO    | [AAPL] p293: 10 items.
# 01:02:05 | INFO    | [AAPL] p294: 10 items.
# 01:02:07 | INFO    | [AAPL] p295: 10 items.
# 01:02:08 | INFO    | [AAPL] p296: 10 items.
# 01:02:11 | INFO    | [AAPL] p297: 10 items.
# 01:02:13 | INFO    | [AAPL] p298: 7 items.
# 01:02:15 | INFO    | [AAPL] p299: 10 items.
# 01:02:20 | INFO    | [AAPL] p300: 10 items.
# 01:02:22 | INFO    | [AAPL] p301: 10 items.
# 01:02:24 | INFO    | [AAPL] p302: 10 items.
# 01:02:26 | INFO    | [AAPL] p303: 10 items.
# 01:02:28 | INFO    | [AAPL] p304: 10 items.
# 01:02:30 | INFO    | [AAPL] p305: 10 items.
# 01:02:32 | INFO    | [AAPL] p306: 10 items.
# 01:02:34 | INFO    | [AAPL] p307: 10 items.
# 01:02:36 | INFO    | [AAPL] p308: 10 items.
# 01:02:38 | INFO    | [AAPL] p309: 10 items.
# 01:02:40 | INFO    | [AAPL] p310: 10 items.
# 01:02:42 | INFO    | [AAPL] p311: 10 items.
# 01:02:44 | INFO    | [AAPL] p312: 10 items.
# 01:02:46 | INFO    | [AAPL] p313: 10 items.
# 01:02:48 | INFO    | [AAPL] p314: 10 items.
# 01:02:50 | INFO    | [AAPL] p315: 9 items.
# 01:02:52 | INFO    | [AAPL] p316: 10 items.
# 01:02:53 | INFO    | [AAPL] p317: 10 items.
# 01:02:56 | INFO    | [AAPL] p318: 10 items.
# 01:02:58 | INFO    | [AAPL] p319: 10 items.
# 01:03:00 | INFO    | [AAPL] p320: 10 items.
# 01:03:02 | INFO    | [AAPL] p321: 10 items.
# 01:03:04 | INFO    | [AAPL] p322: 10 items.
# 01:03:06 | INFO    | [AAPL] p323: 10 items.
# 01:03:09 | INFO    | [AAPL] p324: 10 items.
# 01:03:11 | INFO    | [AAPL] p325: 10 items.
# 01:03:13 | INFO    | [AAPL] p326: 10 items.
# 01:03:18 | INFO    | [AAPL] p327: 10 items.
# 01:03:19 | INFO    | [AAPL] p328: 10 items.
# 01:03:21 | INFO    | [AAPL] p329: 10 items.
# 01:03:23 | INFO    | [AAPL] p330: 10 items.
# 01:03:25 | INFO    | [AAPL] p331: 10 items.
# 01:03:27 | INFO    | [AAPL] p332: 10 items.
# 01:03:29 | INFO    | [AAPL] p333: 10 items.
# 01:03:30 | INFO    | [AAPL] p334: 10 items.
# 01:03:32 | INFO    | [AAPL] p335: 10 items.
# 01:03:34 | INFO    | [AAPL] p336: 10 items.
# 01:03:36 | INFO    | [AAPL] p337: 10 items.
# 01:03:38 | INFO    | [AAPL] p338: 10 items.
# 01:03:40 | INFO    | [AAPL] p339: 10 items.
# 01:03:41 | INFO    | [AAPL] p340: 10 items.
# 01:03:43 | INFO    | [AAPL] p341: 10 items.
# 01:03:45 | INFO    | [AAPL] p342: 10 items.
# 01:03:47 | INFO    | [AAPL] p343: 10 items.
# 01:03:49 | INFO    | [AAPL] p344: 10 items.
# 01:03:51 | INFO    | [AAPL] p345: 10 items.
# 01:05:38 | INFO    | [AAPL] p399: 10 items.
# 01:05:40 | INFO    | [AAPL] p400: 5 items.
# 01:05:42 | INFO    | [AAPL] p401: 10 items.
# 01:05:43 | INFO    | [AAPL] p402: 10 items.
# 01:05:45 | INFO    | [AAPL] p403: 10 items.
# 01:05:47 | INFO    | [AAPL] p404: 10 items.
# 01:05:49 | INFO    | [AAPL] p405: 10 items.
# 01:05:51 | INFO    | [AAPL] p406: 10 items.
# 01:05:53 | INFO    | [AAPL] p407: 10 items.
# 01:05:57 | INFO    | [AAPL] p408: 10 items.
# 01:05:59 | INFO    | [AAPL] p409: 10 items.
# 01:06:01 | INFO    | [AAPL] p410: 10 items.
# 01:06:02 | INFO    | [AAPL] p411: 10 items.
# 01:06:04 | INFO    | [AAPL] p412: 10 items.
# 01:06:06 | INFO    | [AAPL] p413: 10 items.
# 01:06:08 | INFO    | [AAPL] p414: 10 items.
# 01:06:10 | INFO    | [AAPL] p415: 10 items.
# 01:06:12 | INFO    | [AAPL] p416: 10 items.
# 01:06:13 | INFO    | [AAPL] p417: 10 items.
# 01:06:15 | INFO    | [AAPL] p418: 10 items.
# 01:06:17 | INFO    | [AAPL] p419: 10 items.
# 01:06:19 | INFO    | [AAPL] p420: 10 items.
# 01:06:21 | INFO    | [AAPL] p421: 10 items.
# 01:06:23 | INFO    | [AAPL] p422: 10 items.
# 01:06:25 | INFO    | [AAPL] p423: 10 items.
# 01:06:27 | INFO    | [AAPL] p424: 10 items.
# 01:06:30 | INFO    | [AAPL] p425: 10 items.
# 01:06:32 | INFO    | [AAPL] p426: 10 items.
# 01:06:34 | INFO    | [AAPL] p427: 10 items.
# 01:06:36 | INFO    | [AAPL] p428: 10 items.
# 01:06:38 | INFO    | [AAPL] p429: 10 items.
# 01:06:40 | INFO    | [AAPL] p430: 10 items.
# 01:06:41 | INFO    | [AAPL] p431: 10 items.
# 01:06:43 | INFO    | [AAPL] p432: 10 items.
# 01:06:45 | INFO    | [AAPL] p433: 10 items.
# 01:06:47 | INFO    | [AAPL] p434: 10 items.
# 01:06:49 | INFO    | [AAPL] p435: 10 items.
# 01:06:51 | INFO    | [AAPL] p436: 10 items.
# 01:06:53 | INFO    | [AAPL] p437: 10 items.
# 01:06:54 | INFO    | [AAPL] p438: 10 items.
# 01:06:56 | INFO    | [AAPL] p439: 10 items.
# 01:06:59 | INFO    | [AAPL] p440: 10 items.
# 01:07:02 | INFO    | [AAPL] p441: 10 items.
# 01:07:04 | INFO    | [AAPL] p442: 10 items.
# 01:07:06 | INFO    | [AAPL] p443: 10 items.
# 01:07:08 | INFO    | [AAPL] p444: 10 items.
# 01:07:10 | INFO    | [AAPL] p445: 10 items.
# 01:07:12 | INFO    | [AAPL] p446: 10 items.
# 01:07:14 | INFO    | [AAPL] p447: 10 items.
# 01:07:15 | WARNING | HTTP 503 em https://br.investing.com/equities/apple-computer-inc-news/448; retry em 2.2s
# 01:07:19 | INFO    | [AAPL] p448: 10 items.
# 01:07:21 | INFO    | [AAPL] p449: 10 items.
# 01:09:13 | INFO    | [AAPL] p503: 10 items.
# 01:09:15 | INFO    | [AAPL] p504: 10 items.
# 01:09:16 | INFO    | [AAPL] p505: 10 items.
# 01:09:18 | INFO    | [AAPL] p506: 10 items.
# 01:09:23 | INFO    | [AAPL] p507: 10 items.
# 01:09:25 | INFO    | [AAPL] p508: 10 items.
# 01:09:26 | INFO    | [AAPL] p509: 10 items.
# 01:09:28 | INFO    | [AAPL] p510: 10 items.
# 01:09:31 | INFO    | [AAPL] p511: 10 items.
# 01:09:33 | INFO    | [AAPL] p512: 10 items.
# 01:09:35 | INFO    | [AAPL] p513: 10 items.
# 01:09:38 | INFO    | [AAPL] p514: 10 items.
# 01:09:40 | INFO    | [AAPL] p515: 10 items.
# 01:09:41 | INFO    | [AAPL] p516: 10 items.
# 01:09:44 | INFO    | [AAPL] p517: 10 items.
# 01:09:46 | INFO    | [AAPL] p518: 10 items.
# 01:09:48 | INFO    | [AAPL] p519: 10 items.
# 01:09:49 | INFO    | [AAPL] p520: 10 items.
# 01:09:51 | INFO    | [AAPL] p521: 10 items.
# 01:09:53 | INFO    | [AAPL] p522: 10 items.
# 01:09:55 | INFO    | [AAPL] p523: 10 items.
# 01:09:57 | INFO    | [AAPL] p524: 10 items.
# 01:10:00 | INFO    | [AAPL] p525: 10 items.
# 01:10:02 | INFO    | [AAPL] p526: 10 items.
# 01:10:04 | INFO    | [AAPL] p527: 10 items.
# 01:10:06 | INFO    | [AAPL] p528: 10 items.
# 01:10:08 | INFO    | [AAPL] p529: 10 items.
# 01:10:12 | INFO    | [AAPL] p530: 10 items.
# 01:10:14 | INFO    | [AAPL] p531: 10 items.
# 01:10:16 | INFO    | [AAPL] p532: 10 items.
# 01:10:19 | INFO    | [AAPL] p533: 10 items.
# 01:10:21 | INFO    | [AAPL] p534: 10 items.
# 01:10:23 | INFO    | [AAPL] p535: 10 items.
# 01:10:25 | INFO    | [AAPL] p536: 10 items.
# 01:10:27 | INFO    | [AAPL] p537: 10 items.
# 01:10:29 | INFO    | [AAPL] p538: 10 items.
# 01:10:33 | INFO    | [AAPL] p539: 10 items.
# 01:10:35 | INFO    | [AAPL] p540: 10 items.
# 01:10:37 | INFO    | [AAPL] p541: 10 items.
# 01:10:39 | INFO    | [AAPL] p542: 10 items.
# 01:10:41 | INFO    | [AAPL] p543: 10 items.
# 01:10:43 | INFO    | [AAPL] p544: 10 items.
# 01:10:46 | INFO    | [AAPL] p545: 10 items.
# 01:10:48 | INFO    | [AAPL] p546: 10 items.
# 01:10:50 | INFO    | [AAPL] p547: 10 items.
# 01:10:52 | INFO    | [AAPL] p548: 10 items.
# 01:10:54 | INFO    | [AAPL] p549: 10 items.
# 01:10:56 | INFO    | [AAPL] p550: 10 items.
# 01:10:57 | INFO    | [AAPL] p551: 10 items.
# 01:10:59 | INFO    | [AAPL] p552: 10 items.
# 01:11:01 | INFO    | [AAPL] p553: 10 items.
# 01:11:03 | INFO    | [AAPL] p554: 10 items.
# 01:11:05 | INFO    | [AAPL] p555: 10 items.
# 01:11:07 | INFO    | [AAPL] p556: 10 items.
# 01:11:09 | INFO    | [AAPL] p557: 10 items.
# 01:11:11 | INFO    | [AAPL] p558: 10 items.
# 01:11:14 | INFO    | [AAPL] p559: 10 items.
# 01:11:16 | INFO    | [AAPL] p560: 10 items.
# 01:11:18 | INFO    | [AAPL] p561: 10 items.
# 01:11:20 | INFO    | [AAPL] p562: 10 items.
# 01:11:21 | INFO    | [AAPL] p563: 10 items.
# 01:11:23 | INFO    | [AAPL] p564: 10 items.
# 01:11:25 | INFO    | [AAPL] p565: 10 items.
# 01:11:27 | INFO    | [AAPL] p566: 10 items.
# 01:11:29 | INFO    | [AAPL] p567: 10 items.
# 01:11:31 | INFO    | [AAPL] p568: 10 items.
# 01:11:33 | INFO    | [AAPL] p569: 10 items.
# 01:11:36 | INFO    | [AAPL] p570: 10 items.
# 01:11:38 | INFO    | [AAPL] p571: 10 items.
# 01:11:39 | INFO    | [AAPL] p572: 10 items.
# 01:11:41 | INFO    | [AAPL] p573: 10 items.
# 01:11:43 | INFO    | [AAPL] p574: 10 items.
# 01:11:48 | INFO    | [AAPL] p575: 10 items.
# 01:11:50 | INFO    | [AAPL] p576: 10 items.
# 01:11:52 | INFO    | [AAPL] p577: 10 items.
# 01:11:54 | INFO    | [AAPL] p578: 10 items.
# 01:12:00 | WARNING | HTTP 503 em https://br.investing.com/equities/apple-computer-inc-news/579; retry em 2.0s
# 01:12:03 | INFO    | [AAPL] p579: 10 items.
# 01:12:05 | INFO    | [AAPL] p580: 10 items.
# 01:12:07 | INFO    | [AAPL] p581: 10 items.
# 01:12:10 | INFO    | [AAPL] p582: 10 items.
# 01:12:12 | INFO    | [AAPL] p583: 10 items.
# 01:12:14 | INFO    | [AAPL] p584: 10 items.
# 01:12:16 | INFO    | [AAPL] p585: 10 items.
# 01:12:18 | INFO    | [AAPL] p586: 10 items.
# 01:12:19 | INFO    | [AAPL] p587: 10 items.
# 01:12:21 | INFO    | [AAPL] p588: 10 items.
# 01:12:23 | INFO    | [AAPL] p589: 10 items.
# 01:12:25 | INFO    | [AAPL] p590: 10 items.
# 01:12:27 | INFO    | [AAPL] p591: 10 items.
# 01:12:29 | INFO    | [AAPL] p592: 10 items.
# 01:12:31 | INFO    | [AAPL] p593: 10 items.
# 01:12:33 | INFO    | [AAPL] p594: 10 items.
# 01:12:35 | INFO    | [AAPL] p595: 10 items.
# 01:12:37 | INFO    | [AAPL] p596: 10 items.
# 01:12:39 | INFO    | [AAPL] p597: 10 items.
# 01:12:41 | INFO    | [AAPL] p598: 10 items.
# 01:12:43 | INFO    | [AAPL] p599: 10 items.
# 01:12:46 | INFO    | [AAPL] p600: 10 items.
# 01:12:48 | INFO    | [AAPL] p601: 10 items.
# 01:12:50 | INFO    | [AAPL] p602: 10 items.
# 01:12:52 | INFO    | [AAPL] p603: 10 items.
# 01:12:55 | INFO    | [AAPL] p604: 10 items.
# 01:12:57 | INFO    | [AAPL] p605: 10 items.
# 01:12:59 | INFO    | [AAPL] p606: 10 items.
# 01:13:01 | INFO    | [AAPL] p607: 10 items.
# 01:14:56 | INFO    | [AAPL] p661: 10 items.
# 01:14:58 | INFO    | [AAPL] p662: 10 items.
# 01:15:00 | INFO    | [AAPL] p663: 10 items.
# 01:15:02 | INFO    | [AAPL] p664: 10 items.
# 01:15:04 | INFO    | [AAPL] p665: 10 items.
# 01:15:06 | INFO    | [AAPL] p666: 10 items.
# 01:15:09 | INFO    | [AAPL] p667: 10 items.
# 01:15:11 | INFO    | [AAPL] p668: 10 items.
# 01:15:12 | INFO    | [AAPL] p669: 10 items.
# 01:15:14 | INFO    | [AAPL] p670: 10 items.
# 01:15:16 | INFO    | [AAPL] p671: 10 items.
# 01:15:18 | INFO    | [AAPL] p672: 10 items.
# 01:15:20 | INFO    | [AAPL] p673: 10 items.
# 01:15:22 | INFO    | [AAPL] p674: 10 items.
# 01:15:24 | INFO    | [AAPL] p675: 10 items.
# 01:15:26 | INFO    | [AAPL] p676: 10 items.
# 01:15:28 | INFO    | [AAPL] p677: 10 items.
# 01:15:30 | INFO    | [AAPL] p678: 10 items.
# 01:15:32 | INFO    | [AAPL] p679: 10 items.
# 01:15:35 | INFO    | [AAPL] p680: 10 items.
# 01:15:37 | INFO    | [AAPL] p681: 10 items.
# 01:15:39 | INFO    | [AAPL] p682: 10 items.
# 01:15:42 | INFO    | [AAPL] p683: 10 items.
# 01:15:44 | INFO    | [AAPL] p684: 10 items.
# 01:15:45 | INFO    | [AAPL] p685: 10 items.
# 01:15:47 | INFO    | [AAPL] p686: 10 items.
# 01:15:49 | INFO    | [AAPL] p687: 10 items.
# 01:15:51 | INFO    | [AAPL] p688: 10 items.
# 01:15:54 | INFO    | [AAPL] p689: 10 items.
# 01:15:55 | INFO    | [AAPL] p690: 10 items.
# 01:15:58 | INFO    | [AAPL] p691: 10 items.
# 01:16:00 | INFO    | [AAPL] p692: 10 items.
# 01:16:02 | INFO    | [AAPL] p693: 10 items.
# 01:16:04 | INFO    | [AAPL] p694: 10 items.
# 01:16:06 | INFO    | [AAPL] p695: 10 items.
# 01:16:08 | INFO    | [AAPL] p696: 10 items.
# 01:16:10 | INFO    | [AAPL] p697: 10 items.
# 01:16:12 | INFO    | [AAPL] p698: 10 items.
# 01:16:14 | INFO    | [AAPL] p699: 10 items.
# 01:16:16 | INFO    | [AAPL] p700: 10 items.
# 01:16:18 | INFO    | [AAPL] p701: 10 items.
# 01:16:20 | INFO    | [AAPL] p702: 10 items.
# 01:16:22 | INFO    | [AAPL] p703: 10 items.
# 01:16:24 | INFO    | [AAPL] p704: 10 items.
# 01:16:28 | INFO    | [AAPL] p705: 10 items.
# 01:16:30 | INFO    | [AAPL] p706: 10 items.
# 01:16:33 | INFO    | [AAPL] p707: 10 items.
# 01:16:35 | INFO    | [AAPL] p708: 10 items.
# 01:16:38 | INFO    | [AAPL] p709: 10 items.
# 01:16:40 | INFO    | [AAPL] p710: 10 items.
# 01:16:42 | INFO    | [AAPL] p711: 10 items.
# 01:16:44 | INFO    | [AAPL] p712: 10 items.
# 01:16:47 | INFO    | [AAPL] p713: 10 items.
# 01:18:49 | INFO    | [AAPL] p767: 10 items.
# 01:18:51 | INFO    | [AAPL] p768: 10 items.
# 01:18:53 | INFO    | [AAPL] p769: 10 items.
# 01:18:55 | INFO    | [AAPL] p770: 10 items.
# 01:18:57 | INFO    | [AAPL] p771: 10 items.
# 01:18:59 | INFO    | [AAPL] p772: 10 items.
# 01:19:01 | INFO    | [AAPL] p773: 10 items.
# 01:19:03 | INFO    | [AAPL] p774: 10 items.
# 01:19:05 | INFO    | [AAPL] p775: 10 items.
# 01:19:07 | INFO    | [AAPL] p776: 10 items.
# 01:19:09 | INFO    | [AAPL] p777: 10 items.
# 01:19:11 | INFO    | [AAPL] p778: 10 items.
# 01:19:12 | INFO    | [AAPL] p779: 6 items.
# 01:19:14 | INFO    | [AAPL] p780: 0 items.
# 01:19:16 | INFO    | [AAPL] p781: 0 items.
# 01:19:18 | INFO    | [AAPL] p782: 0 items.
# 01:19:20 | INFO    | [AAPL] p783: 0 items.
# 01:19:22 | INFO    | [AAPL] p784: 0 items.
# 01:19:24 | INFO    | [AAPL] p785: 0 items.
# 01:19:26 | INFO    | [AAPL] p786: 0 items.
# 01:19:28 | INFO    | [AAPL] p787: 0 items.
# 01:19:30 | INFO    | [AAPL] p788: 0 items.
# 01:19:33 | INFO    | [AAPL] p789: 0 items.
# 01:19:34 | INFO    | [AAPL] p790: 0 items.
# 01:19:37 | INFO    | [AAPL] p791: 0 items.
# 01:19:39 | INFO    | [AAPL] p792: 0 items.
# 01:19:41 | INFO    | [AAPL] p793: 0 items.
# 01:19:43 | INFO    | [AAPL] p794: 0 items.
# 01:19:45 | INFO    | [AAPL] p795: 0 items.
# 01:19:46 | INFO    | [AAPL] p796: 0 items.
# 01:19:48 | INFO    | [AAPL] p797: 0 items.
# 01:19:50 | INFO    | [AAPL] p798: 0 items.
# 01:19:52 | INFO    | [AAPL] p799: 0 items.
# 01:19:54 | INFO    | [AAPL] p800: 0 items.
# 01:19:56 | INFO    | [AAPL] p801: 0 items.
# 01:19:58 | INFO    | [AAPL] p802: 0 items.
# 01:20:00 | INFO    | [AAPL] p803: 0 items.
# 01:20:02 | INFO    | [AAPL] p804: 0 items.
# 01:20:04 | INFO    | [AAPL] p805: 0 items.
# 01:20:05 | INFO    | [AAPL] p806: 0 items.
# 01:20:08 | INFO    | [AAPL] p807: 0 items.
# 01:20:10 | INFO    | [AAPL] p808: 0 items.
# 01:20:12 | INFO    | [AAPL] p809: 0 items.
# 01:20:14 | INFO    | [AAPL] p810: 0 items.
# 01:20:16 | INFO    | [AAPL] p811: 0 items.
# 01:20:17 | INFO    | [AAPL] p812: 0 items.
# 01:20:19 | INFO    | [AAPL] p813: 0 items.
# 01:20:22 | INFO    | [AAPL] p814: 0 items.
# 01:20:24 | INFO    | [AAPL] p815: 0 items.
# 01:20:26 | INFO    | [AAPL] p816: 0 items.
# 01:20:28 | INFO    | [AAPL] p817: 0 items.
# 01:20:29 | INFO    | [AAPL] p818: 0 items.
# 01:20:31 | INFO    | [AAPL] p819: 0 items.
# 01:20:33 | INFO    | [AAPL] p820: 0 items.
# 01:20:35 | INFO    | [AAPL] p821: 0 items.
# 01:20:37 | INFO    | [AAPL] p822: 0 items.
# 01:20:39 | INFO    | [AAPL] p823: 0 items.
# 01:20:40 | INFO    | [AAPL] p824: 0 items.
# 01:20:43 | INFO    | [AAPL] p825: 0 items.
# 01:20:45 | INFO    | [AAPL] p826: 0 items.
# 01:20:47 | INFO    | [AAPL] p827: 0 items.
# 01:20:49 | INFO    | [AAPL] p828: 0 items.
# 01:20:51 | INFO    | [AAPL] p829: 0 items.
# 01:20:58 | INFO    | [AAPL] p830: 0 items.
# 01:21:00 | INFO    | [AAPL] p831: 0 items.
# 01:21:03 | INFO    | [AAPL] p832: 0 items.
# 01:21:05 | INFO    | [AAPL] p833: 0 items.
# 01:21:07 | INFO    | [AAPL] p834: 0 items.
# 01:21:09 | INFO    | [AAPL] p835: 0 items.
# 01:21:11 | INFO    | [AAPL] p836: 0 items.
# 01:21:13 | INFO    | [AAPL] p837: 0 items.
# 01:21:15 | INFO    | [AAPL] p838: 0 items.
# 01:21:17 | INFO    | [AAPL] p839: 0 items.
# 01:21:19 | INFO    | [AAPL] p840: 0 items.
# 01:21:21 | INFO    | [AAPL] p841: 0 items.
# 01:21:22 | INFO    | [AAPL] p842: 0 items.
# 01:21:24 | INFO    | [AAPL] p843: 0 items.
# 01:21:26 | INFO    | [AAPL] p844: 0 items.
# 01:21:28 | INFO    | [AAPL] p845: 0 items.
# 01:21:30 | INFO    | [AAPL] p846: 0 items.
# 01:21:32 | INFO    | [AAPL] p847: 0 items.
# 01:21:34 | INFO    | [AAPL] p848: 0 items.
# 01:21:36 | INFO    | [AAPL] p849: 0 items.
# 01:21:38 | INFO    | [AAPL] p850: 0 items.
# 01:21:40 | INFO    | [AAPL] p851: 0 items.
# 01:21:42 | INFO    | [AAPL] p852: 0 items.
# 01:21:44 | INFO    | [AAPL] p853: 0 items.
# 01:21:46 | INFO    | [AAPL] p854: 0 items.
# 01:21:48 | INFO    | [AAPL] p855: 0 items.
# 01:21:50 | INFO    | [AAPL] p856: 0 items.
# 01:21:51 | INFO    | [AAPL] p857: 0 items.
# Empresas:   2%|▏         | 1/43 [30:57<21:40:18, 1857.57s/it]01:22:44 | INFO    | [MSFT] p1: 10 items.
# 01:22:46 | INFO    | [MSFT] p2: 10 items.
# 01:22:48 | INFO    | [MSFT] p3: 10 items.
# 01:22:50 | INFO    | [MSFT] p4: 10 items.
# 01:22:52 | INFO    | [MSFT] p5: 10 items.
# 01:22:54 | INFO    | [MSFT] p6: 10 items.
# 01:22:57 | INFO    | [MSFT] p7: 10 items.
# 01:22:59 | INFO    | [MSFT] p8: 10 items.
# 01:23:01 | INFO    | [MSFT] p9: 10 items.
# 01:23:03 | INFO    | [MSFT] p10: 10 items.
# 01:23:05 | INFO    | [MSFT] p11: 10 items.
# 01:23:07 | INFO    | [MSFT] p12: 10 items.
# 01:23:09 | INFO    | [MSFT] p13: 10 items.
# 01:23:11 | INFO    | [MSFT] p14: 10 items.
# 06:03:45 | INFO    | [AMD] p88: 10 items.
# 06:03:47 | INFO    | [AMD] p89: 10 items.
# 06:03:49 | INFO    | [AMD] p90: 10 items.
# 06:03:51 | INFO    | [AMD] p91: 10 items.
# 06:03:53 | INFO    | [AMD] p92: 10 items.
# 06:03:55 | INFO    | [AMD] p93: 10 items.
# 06:03:58 | INFO    | [AMD] p94: 10 items.
# 06:04:00 | INFO    | [AMD] p95: 10 items.
# 06:04:02 | INFO    | [AMD] p96: 10 items.
# 06:04:05 | INFO    | [AMD] p97: 10 items.
# 06:04:07 | INFO    | [AMD] p98: 10 items.
# 06:04:10 | INFO    | [AMD] p99: 10 items.
# 06:04:12 | INFO    | [AMD] p100: 10 items.
# 06:04:14 | INFO    | [AMD] p101: 10 items.
# 06:04:16 | INFO    | [AMD] p102: 10 items.
# 06:04:18 | INFO    | [AMD] p103: 10 items.
# 06:04:20 | INFO    | [AMD] p104: 10 items.
# 06:04:22 | INFO    | [AMD] p105: 10 items.
# 06:04:24 | INFO    | [AMD] p106: 10 items.
# 06:04:26 | INFO    | [AMD] p107: 10 items.
# 06:04:28 | INFO    | [AMD] p108: 10 items.
# 06:04:30 | INFO    | [AMD] p109: 10 items.
# 06:04:33 | INFO    | [AMD] p110: 10 items.
# 06:04:35 | INFO    | [AMD] p111: 10 items.
# 06:04:37 | INFO    | [AMD] p112: 10 items.
# 06:04:39 | INFO    | [AMD] p113: 10 items.
# 06:04:41 | INFO    | [AMD] p114: 10 items.
# 06:04:43 | INFO    | [AMD] p115: 10 items.
# 06:04:45 | INFO    | [AMD] p116: 10 items.
# 06:04:47 | INFO    | [AMD] p117: 10 items.
# 06:04:49 | INFO    | [AMD] p118: 10 items.
# 06:04:51 | INFO    | [AMD] p119: 10 items.
# 06:04:53 | INFO    | [AMD] p120: 10 items.
# 06:04:55 | WARNING | HTTP 503 em https://www.investing.com/equities/adv-micro-device-news/121; retry em 2.3s
# 06:04:58 | INFO    | [AMD] p121: 10 items.
# 06:05:00 | INFO    | [AMD] p122: 10 items.
# 06:05:02 | INFO    | [AMD] p123: 10 items.
# 06:05:04 | INFO    | [AMD] p124: 10 items.
# 06:05:07 | INFO    | [AMD] p125: 10 items.
# 06:05:09 | INFO    | [AMD] p126: 10 items.
# 06:05:11 | INFO    | [AMD] p127: 10 items.
# 06:05:13 | INFO    | [AMD] p128: 10 items.
# 06:05:15 | INFO    | [AMD] p129: 10 items.
# 06:05:17 | INFO    | [AMD] p130: 10 items.
# 06:05:20 | INFO    | [AMD] p131: 10 items.
# 06:05:22 | INFO    | [AMD] p132: 10 items.
# 06:05:24 | INFO    | [AMD] p133: 10 items.
# 06:05:26 | INFO    | [AMD] p134: 10 items.
# 06:05:29 | INFO    | [AMD] p135: 10 items.
# 06:05:31 | INFO    | [AMD] p136: 10 items.
# 06:05:33 | INFO    | [AMD] p137: 10 items.
# 06:05:35 | INFO    | [AMD] p138: 10 items.
# 06:05:37 | INFO    | [AMD] p139: 10 items.
# 06:05:39 | INFO    | [AMD] p140: 10 items.
# 06:05:41 | INFO    | [AMD] p141: 10 items.
# 06:05:43 | INFO    | [AMD] p142: 10 items.
# 06:05:45 | INFO    | [AMD] p143: 10 items.
# 06:05:48 | INFO    | [AMD] p144: 10 items.
# 06:05:50 | INFO    | [AMD] p145: 10 items.
# 06:05:52 | INFO    | [AMD] p146: 10 items.
# 06:05:54 | WARNING | HTTP 500 em https://www.investing.com/equities/adv-micro-device-news/147; retry em 1.7s
# 06:05:57 | INFO    | [AMD] p147: 10 items.
# 06:05:59 | INFO    | [AMD] p148: 10 items.
# 06:06:01 | INFO    | [AMD] p149: 10 items.
# 06:06:03 | INFO    | [AMD] p150: 10 items.
# 06:06:05 | INFO    | [AMD] p151: 10 items.
# 06:06:07 | INFO    | [AMD] p152: 10 items.
# 06:06:09 | INFO    | [AMD] p153: 10 items.
# 06:06:11 | INFO    | [AMD] p154: 10 items.
# 06:06:13 | INFO    | [AMD] p155: 10 items.
# 06:06:15 | INFO    | [AMD] p156: 10 items.
# 06:06:17 | INFO    | [AMD] p157: 10 items.
# 06:06:19 | INFO    | [AMD] p158: 10 items.
# 06:06:21 | INFO    | [AMD] p159: 10 items.
# 06:06:23 | INFO    | [AMD] p160: 10 items.
# 06:06:26 | INFO    | [AMD] p161: 10 items.
# 06:06:27 | INFO    | [AMD] p162: 10 items.
# 06:06:30 | INFO    | [AMD] p163: 10 items.
# 06:06:32 | INFO    | [AMD] p164: 10 items.
# 06:06:35 | INFO    | [AMD] p165: 10 items.
# 06:06:37 | INFO    | [AMD] p166: 10 items.
# 06:06:39 | INFO    | [AMD] p167: 10 items.
# 06:06:41 | INFO    | [AMD] p168: 10 items.
# 06:06:43 | INFO    | [AMD] p169: 10 items.
# 06:06:45 | INFO    | [AMD] p170: 10 items.
# 06:06:47 | INFO    | [AMD] p171: 10 items.
# 06:06:49 | INFO    | [AMD] p172: 10 items.
# 06:06:51 | INFO    | [AMD] p173: 10 items.
# 06:06:53 | INFO    | [AMD] p174: 10 items.
# 06:06:55 | INFO    | [AMD] p175: 10 items.
# 06:06:57 | INFO    | [AMD] p176: 10 items.
# 06:06:59 | INFO    | [AMD] p177: 10 items.
# 06:07:01 | INFO    | [AMD] p178: 10 items.
# 06:07:03 | INFO    | [AMD] p179: 10 items.
# 06:07:06 | INFO    | [AMD] p180: 10 items.
# 06:07:08 | INFO    | [AMD] p181: 10 items.
# 06:07:10 | INFO    | [AMD] p182: 10 items.
# 06:07:13 | INFO    | [AMD] p183: 10 items.
# 06:07:15 | INFO    | [AMD] p184: 10 items.
# 06:07:16 | WARNING | HTTP 503 em https://www.investing.com/equities/adv-micro-device-news/185; retry em 2.2s
# 06:07:19 | INFO    | [AMD] p185: 10 items.
# 06:07:21 | INFO    | [AMD] p186: 10 items.
# 06:07:23 | INFO    | [AMD] p187: 10 items.
# 06:07:25 | INFO    | [AMD] p188: 10 items.
# 06:07:27 | INFO    | [AMD] p189: 10 items.
# 06:07:29 | INFO    | [AMD] p190: 10 items.
# 06:07:31 | INFO    | [AMD] p191: 10 items.
# 06:07:33 | INFO    | [AMD] p192: 10 items.
# 06:07:35 | INFO    | [AMD] p193: 10 items.
# 06:07:37 | INFO    | [AMD] p194: 10 items.
# 06:07:40 | INFO    | [AMD] p195: 10 items.
# 06:07:42 | INFO    | [AMD] p196: 10 items.
# 06:07:44 | INFO    | [AMD] p197: 10 items.
# 06:07:46 | INFO    | [AMD] p198: 10 items.
# 06:07:48 | INFO    | [AMD] p199: 10 items.
# 06:07:50 | INFO    | [AMD] p200: 10 items.
# 06:07:52 | INFO    | [AMD] p201: 10 items.
# 06:07:54 | INFO    | [AMD] p202: 10 items.
# 06:07:55 | INFO    | [AMD] p203: 10 items.
# 06:07:57 | INFO    | [AMD] p204: 10 items.
# 06:07:59 | INFO    | [AMD] p205: 10 items.
# 06:08:01 | INFO    | [AMD] p206: 10 items.
# 06:08:04 | INFO    | [AMD] p207: 10 items.
# 06:08:06 | INFO    | [AMD] p208: 10 items.
# 06:08:08 | INFO    | [AMD] p209: 10 items.
# 06:08:10 | INFO    | [AMD] p210: 10 items.
# 06:08:12 | INFO    | [AMD] p211: 10 items.
# 06:08:14 | INFO    | [AMD] p212: 10 items.
# 06:08:16 | INFO    | [AMD] p213: 10 items.
# 06:08:17 | INFO    | [AMD] p214: 10 items.
# 06:08:19 | INFO    | [AMD] p215: 10 items.
# 06:08:21 | INFO    | [AMD] p216: 10 items.
# 06:08:23 | INFO    | [AMD] p217: 10 items.
# 06:08:25 | INFO    | [AMD] p218: 10 items.
# 06:08:27 | INFO    | [AMD] p219: 10 items.
# 06:08:29 | INFO    | [AMD] p220: 10 items.
# 06:08:31 | INFO    | [AMD] p221: 10 items.
# 06:08:34 | INFO    | [AMD] p222: 10 items.
# 06:08:37 | INFO    | [AMD] p223: 10 items.
# 06:08:39 | INFO    | [AMD] p224: 10 items.
# 06:08:41 | INFO    | [AMD] p225: 10 items.
# 06:08:43 | INFO    | [AMD] p226: 10 items.
# 06:08:45 | INFO    | [AMD] p227: 10 items.
# 06:08:47 | INFO    | [AMD] p228: 10 items.
# 06:08:49 | INFO    | [AMD] p229: 10 items.
# 06:08:51 | INFO    | [AMD] p230: 10 items.
# 06:08:53 | INFO    | [AMD] p231: 10 items.
# 06:08:55 | INFO    | [AMD] p232: 10 items.
# 06:08:57 | INFO    | [AMD] p233: 10 items.
# 06:08:59 | INFO    | [AMD] p234: 10 items.
# 06:09:01 | INFO    | [AMD] p235: 10 items.
# 06:09:03 | INFO    | [AMD] p236: 10 items.
# 06:09:05 | INFO    | [AMD] p237: 10 items.
# 06:09:07 | INFO    | [AMD] p238: 10 items.
# 06:09:09 | INFO    | [AMD] p239: 10 items.
# 06:09:11 | INFO    | [AMD] p240: 10 items.
# 06:09:13 | INFO    | [AMD] p241: 10 items.
# 06:09:16 | INFO    | [AMD] p242: 10 items.
# 06:09:18 | INFO    | [AMD] p243: 10 items.
# 06:09:20 | INFO    | [AMD] p244: 10 items.
# 06:09:22 | INFO    | [AMD] p245: 10 items.
# 06:09:24 | INFO    | [AMD] p246: 10 items.
# 06:09:26 | INFO    | [AMD] p247: 10 items.
# 06:09:28 | INFO    | [AMD] p248: 10 items.
# 06:09:30 | INFO    | [AMD] p249: 10 items.
# 06:09:32 | INFO    | [AMD] p250: 10 items.
# 06:09:34 | INFO    | [AMD] p251: 10 items.
# 06:09:36 | INFO    | [AMD] p252: 10 items.
# 06:09:38 | INFO    | [AMD] p253: 10 items.
# 06:09:40 | INFO    | [AMD] p254: 10 items.
# 06:09:42 | INFO    | [AMD] p255: 10 items.
# 06:09:44 | INFO    | [AMD] p256: 10 items.
# 06:09:46 | INFO    | [AMD] p257: 10 items.
# 06:09:48 | INFO    | [AMD] p258: 10 items.
# 06:09:50 | INFO    | [AMD] p259: 10 items.
# 06:09:52 | INFO    | [AMD] p260: 10 items.
# 06:09:54 | INFO    | [AMD] p261: 10 items.
# 06:09:56 | INFO    | [AMD] p262: 10 items.
# 06:09:59 | INFO    | [AMD] p263: 10 items.
# 06:10:01 | INFO    | [AMD] p264: 10 items.
# 06:10:03 | INFO    | [AMD] p265: 10 items.
# 06:10:05 | INFO    | [AMD] p266: 10 items.
# 06:10:07 | INFO    | [AMD] p267: 10 items.
# 06:10:09 | INFO    | [AMD] p268: 10 items.
# 06:10:11 | INFO    | [AMD] p269: 10 items.
# 06:10:14 | INFO    | [AMD] p270: 10 items.
# 06:10:17 | INFO    | [AMD] p271: 10 items.
# 06:10:19 | INFO    | [AMD] p272: 10 items.
# 06:10:21 | INFO    | [AMD] p273: 10 items.
# 06:10:23 | INFO    | [AMD] p274: 10 items.
# 06:10:24 | INFO    | [AMD] p275: 10 items.
# 06:10:26 | INFO    | [AMD] p276: 10 items.
# 06:10:28 | INFO    | [AMD] p277: 10 items.
# 06:10:30 | INFO    | [AMD] p278: 10 items.
# 06:10:34 | INFO    | [AMD] p279: 10 items.
# 06:10:36 | INFO    | [AMD] p280: 10 items.
# 06:10:37 | INFO    | [AMD] p281: 10 items.
# 06:10:40 | INFO    | [AMD] p282: 10 items.
# 06:10:42 | INFO    | [AMD] p283: 10 items.
# 06:10:43 | INFO    | [AMD] p284: 10 items.
# 06:10:45 | INFO    | [AMD] p285: 10 items.
# 06:10:47 | INFO    | [AMD] p286: 10 items.
# 06:10:49 | INFO    | [AMD] p287: 10 items.
# 06:10:51 | INFO    | [AMD] p288: 10 items.
# 06:10:53 | INFO    | [AMD] p289: 10 items.
# 06:10:56 | INFO    | [AMD] p290: 10 items.
# 06:10:58 | INFO    | [AMD] p291: 10 items.
# 06:11:00 | INFO    | [AMD] p292: 10 items.
# 06:11:02 | INFO    | [AMD] p293: 10 items.
# 06:11:06 | INFO    | [AMD] p294: 10 items.
# 06:11:08 | INFO    | [AMD] p295: 10 items.
# 06:11:10 | INFO    | [AMD] p296: 10 items.
# 06:11:12 | INFO    | [AMD] p297: 10 items.
# 06:11:14 | INFO    | [AMD] p298: 10 items.
# 06:11:16 | INFO    | [AMD] p299: 10 items.
# 06:11:18 | INFO    | [AMD] p300: 10 items.
# 06:11:20 | INFO    | [AMD] p301: 10 items.
# 06:11:22 | INFO    | [AMD] p302: 10 items.
# 06:11:24 | INFO    | [AMD] p303: 10 items.
# 06:11:26 | INFO    | [AMD] p304: 10 items.
# 06:11:28 | INFO    | [AMD] p305: 10 items.
# 06:11:30 | INFO    | [AMD] p306: 10 items.
# 06:11:32 | INFO    | [AMD] p307: 10 items.
# 06:11:34 | INFO    | [AMD] p308: 10 items.
# 06:11:37 | INFO    | [AMD] p309: 10 items.
# 06:11:39 | INFO    | [AMD] p310: 10 items.
# 06:11:41 | INFO    | [AMD] p311: 10 items.
# 06:11:43 | INFO    | [AMD] p312: 10 items.
# 06:11:45 | INFO    | [AMD] p313: 10 items.
# 06:11:47 | INFO    | [AMD] p314: 10 items.
# 06:11:49 | INFO    | [AMD] p315: 10 items.
# 06:11:51 | INFO    | [AMD] p316: 10 items.
# 06:11:53 | INFO    | [AMD] p317: 10 items.
# 06:11:55 | INFO    | [AMD] p318: 10 items.
# 06:11:57 | INFO    | [AMD] p319: 10 items.
# 06:11:59 | INFO    | [AMD] p320: 10 items.
# 06:12:01 | INFO    | [AMD] p321: 10 items.
# 06:12:03 | INFO    | [AMD] p322: 10 items.
# 06:12:05 | INFO    | [AMD] p323: 10 items.
# 06:12:08 | INFO    | [AMD] p324: 10 items.
# 06:12:10 | INFO    | [AMD] p325: 10 items.
# 06:12:15 | INFO    | [AMD] p326: 10 items.
# 06:12:17 | INFO    | [AMD] p327: 10 items.
# 06:12:19 | INFO    | [AMD] p328: 10 items.
# 06:12:21 | INFO    | [AMD] p329: 10 items.
# 06:12:24 | INFO    | [AMD] p330: 10 items.
# 06:12:26 | INFO    | [AMD] p331: 10 items.
# 06:12:28 | INFO    | [AMD] p332: 10 items.
# 06:12:30 | INFO    | [AMD] p333: 10 items.
# 06:12:32 | INFO    | [AMD] p334: 10 items.
# 06:12:34 | INFO    | [AMD] p335: 10 items.
# 06:12:36 | INFO    | [AMD] p336: 10 items.
# 06:12:38 | INFO    | [AMD] p337: 10 items.
# 06:12:41 | INFO    | [AMD] p338: 10 items.
# 06:12:45 | INFO    | [AMD] p339: 10 items.
# 06:12:47 | INFO    | [AMD] p340: 10 items.
# 06:12:49 | INFO    | [AMD] p341: 10 items.
# 06:12:52 | INFO    | [AMD] p342: 10 items.
# 06:12:54 | INFO    | [AMD] p343: 10 items.
# 06:12:57 | INFO    | [AMD] p344: 10 items.
# 06:12:59 | INFO    | [AMD] p345: 10 items.
# 06:13:01 | INFO    | [AMD] p346: 10 items.
# 06:13:03 | INFO    | [AMD] p347: 10 items.
# 06:13:05 | INFO    | [AMD] p348: 10 items.
# 06:13:08 | INFO    | [AMD] p349: 10 items.
# 06:13:10 | INFO    | [AMD] p350: 10 items.
# 06:13:12 | INFO    | [AMD] p351: 10 items.
# 06:13:15 | INFO    | [AMD] p352: 10 items.
# 06:13:17 | INFO    | [AMD] p353: 10 items.
# 06:13:19 | INFO    | [AMD] p354: 10 items.
# 06:13:21 | INFO    | [AMD] p355: 10 items.
# 06:13:23 | INFO    | [AMD] p356: 10 items.
# 06:15:23 | INFO    | [AMD] p412: 0 items.
# 06:15:25 | INFO    | [AMD] p413: 0 items.
# 06:15:27 | INFO    | [AMD] p414: 0 items.
# 06:15:29 | INFO    | [AMD] p415: 0 items.
# 06:15:31 | INFO    | [AMD] p416: 0 items.
# 06:15:33 | INFO    | [AMD] p417: 0 items.
# 06:15:36 | INFO    | [AMD] p418: 0 items.
# 06:15:38 | INFO    | [AMD] p419: 0 items.
# 06:15:40 | INFO    | [AMD] p420: 0 items.
# 06:15:42 | INFO    | [AMD] p421: 0 items.
# 06:15:44 | INFO    | [AMD] p422: 0 items.
# 06:15:46 | INFO    | [AMD] p423: 0 items.
# 06:15:48 | INFO    | [AMD] p424: 0 items.
# 06:15:50 | INFO    | [AMD] p425: 0 items.
# 06:15:52 | INFO    | [AMD] p426: 0 items.
# 06:15:54 | INFO    | [AMD] p427: 0 items.
# 06:15:56 | INFO    | [AMD] p428: 0 items.
# 06:15:58 | INFO    | [AMD] p429: 0 items.
# 06:16:00 | INFO    | [AMD] p430: 0 items.
# 06:16:02 | INFO    | [AMD] p431: 0 items.
# 06:16:04 | INFO    | [AMD] p432: 0 items.
# 06:16:06 | INFO    | [AMD] p433: 0 items.
# 06:16:09 | INFO    | [AMD] p434: 0 items.
# 06:16:11 | INFO    | [AMD] p435: 0 items.
# 06:16:13 | INFO    | [AMD] p436: 0 items.
# 06:16:15 | INFO    | [AMD] p437: 0 items.
# 06:16:17 | INFO    | [AMD] p438: 0 items.
# 06:16:20 | INFO    | [AMD] p439: 0 items.
# 06:16:22 | INFO    | [AMD] p440: 0 items.
# 06:16:24 | INFO    | [AMD] p441: 0 items.
# 06:16:26 | INFO    | [AMD] p442: 0 items.
# 06:16:28 | INFO    | [AMD] p443: 0 items.
# 06:16:30 | INFO    | [AMD] p444: 0 items.
# Empresas:  44%|████▍     | 19/43 [5:25:36<3:56:03, 590.16s/it]06:16:31 | INFO    | [KO] p1: 10 items.
# 06:16:33 | INFO    | [KO] p2: 10 items.
# 06:16:31 | INFO    | [KO] p3: 10 items.

# %%
from __future__ import annotations
import re
import time
import uuid
import os
import random
import argparse
from pathlib import Path
from typing import Optional, List, Dict
from datetime import datetime, timedelta
from zoneinfo import ZoneInfo

import pandas as pd
import requests
from bs4 import BeautifulSoup
from dateutil import parser as du
from tqdm import tqdm
import logging

# ---------------- Config & Globals ----------------
SP_TZ = ZoneInfo("America/Sao_Paulo")

DEFAULT_EXCEL = "../data/BaseRefAtivos.xlsx"
DEFAULT_OUT = "../data/investing_news.parquet"
DEFAULT_MAX_PAGES = 1400

HEADERS = {
    "User-Agent": (
        "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
        "AppleWebKit/537.36 (KHTML, like Gecko) "
        "Chrome/127.0.0.0 Safari/537.36"
    ),
    "Accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7",
    "Accept-Language": "pt-BR,pt;q=0.9,en-US;q=0.8,en;q=0.7",
    "Referer": "https://br.investing.com/",
    "DNT": "1",
    "Upgrade-Insecure-Requests": "1",
    "Sec-Fetch-Dest": "document",
    "Sec-Fetch-Mode": "navigate",
}

SESSION = requests.Session()
SESSION.headers.update(HEADERS)

RELATIVE_REGEX = re.compile(
    r"(?P<num>\d+)\s*(?P<unit>min|mins|minutos|minuto|hora|horas|dia|dias)\s*atr[aá]s",
    flags=re.IGNORECASE,
)

# ---------------- Logging ----------------
def setup_logging(verbose: bool = False, debug: bool = False) -> None:
    level = logging.INFO
    if verbose or debug:
        level = logging.DEBUG
    logging.basicConfig(
        level=level,
        format="%(asctime)s | %(levelname)-7s | %(message)s",
        datefmt="%H:%M:%S",
    )

log = logging.getLogger(__name__)

# ---------------- Utils ----------------
def normalize_news_url(url: str) -> str:
    """Garante base ...-news e remove sufixo /<n> para paginar manualmente."""
    url = (url or "").strip()
    if not url:
        return url
    if url.endswith("-new"):
        url = url + "s"
    url = re.sub(r"/+$", "", url)
    m = re.search(r"/(\d+)$", url)
    if m:
        url = url[: - (len(m.group(0)))]
    return url

def page_url(url_base: str, page: int) -> str:
    return f"{url_base}/{page}"

def parse_datetime_from_time_tag(time_tag) -> Optional[datetime]:
    if time_tag is None:
        return None

    text = (time_tag.get_text() or "").strip().lower()
    m = RELATIVE_REGEX.search(text)
    if m:
        num = int(m.group("num"))
        unit = m.group("unit")
        now_sp = datetime.now(SP_TZ)

        if unit.startswith("min"):
            dt = now_sp - timedelta(minutes=num)
        elif unit.startswith("hora"):
            dt = now_sp - timedelta(hours=num)
        else:
            dt = now_sp - timedelta(days=num)
        return dt

    dt_attr = time_tag.get("datetime")
    if dt_attr:
        try:
            dt = du.parse(dt_attr)
            if dt.tzinfo is None:
                dt = dt.replace(tzinfo=SP_TZ)
            return dt.astimezone(SP_TZ)
        except Exception as e:
            log.debug(f"Falha parse datetime attr '{dt_attr}': {e}")

    try:
        dt = du.parse(text, dayfirst=True, fuzzy=True, languages=["pt"])
        if dt is not None:
            if dt.tzinfo is None:
                dt = dt.replace(tzinfo=SP_TZ)
            return dt.astimezone(SP_TZ)
    except Exception as e:
        log.debug(f"Falha parse texto de data '{text}': {e}")

    return None

def deduce_country_language_from_url(url: str) -> tuple[str, str]:
    if "br.investing.com" in url:
        return ("BR", "pt-BR")
    return ("", "")

def make_news_id(url: str, title: str) -> str:
    base = (url or "").strip() + "||" + (title or "").strip()
    return str(uuid.uuid5(uuid.NAMESPACE_URL, base))

def html_debug_dump(html: str, company: str, page: int, outdir: Path) -> None:
    outdir.mkdir(parents=True, exist_ok=True)
    fn = outdir / f"{safe_filename(company)}_p{page:04d}.html"
    try:
        fn.write_text(html, encoding="utf-8")
        log.debug(f"HTML salvo para debug: {fn}")
    except Exception as e:
        log.warning(f"Falha ao salvar HTML de debug: {e}")

def safe_filename(s: str) -> str:
    return re.sub(r"[^A-Za-z0-9._-]+", "_", s.strip())

# ---------------- HTTP com backoff ----------------
def fetch(url: str, max_retries: int = 5, timeout: int = 25) -> Optional[requests.Response]:
    for i in range(max_retries):
        try:
            r = SESSION.get(url, timeout=timeout)
            if r.status_code == 200:
                return r
            if r.status_code in (404, 410):
                log.info(f"HTTP {r.status_code} em {url} (provável fim).")
                return None
            if r.status_code in (429, 500, 502, 503, 504):
                wait = (1.5 * (i + 1)) + random.random()
                log.warning(f"HTTP {r.status_code} em {url}; retry em {wait:.1f}s")
                time.sleep(wait)
                continue
            log.warning(f"HTTP {r.status_code} em {url}; sem retry programado.")
            return None
        except requests.RequestException as e:
            wait = (1.2 * (i + 1)) + random.random()
            log.warning(f"Erro rede: {e}; retry em {wait:.1f}s")
            time.sleep(wait)
    log.error(f"Falhou após {max_retries} tentativas: {url}")
    return None

# ---------------- Parsing ----------------
def parse_news_items(html: str, ticker: str, sector: str) -> List[Dict]:
    soup = BeautifulSoup(html, "html.parser")
    ul = soup.find("ul", attrs={"data-test": "news-list"})
    if not ul:
        log.debug("Ul[data-test='news-list'] não encontrada — página pode ter mudado.")
        return []

    items: List[Dict] = []
    arts = ul.select("article[data-test='article-item']")
    if not arts:
        log.debug("Nenhum article[data-test='article-item'] encontrado nesta página.")
        return []

    for art in arts:
        a_title = art.select_one("a[data-test='article-title-link']")
        if not a_title:
            log.debug("a[data-test='article-title-link'] ausente em um article; pulando.")
            continue

        headline = (a_title.get_text() or "").strip()
        url = a_title.get("href") or ""
        if url.startswith("/"):
            url = "https://br.investing.com" + url

        a_provider = art.select_one("a[data-test='article-provider-link']")
        source = (a_provider.get_text().strip() if a_provider else "").strip()

        t = art.select_one("time[data-test='article-publish-date']")
        dt = parse_datetime_from_time_tag(t)

        country, language = deduce_country_language_from_url(url)
        _id = make_news_id(url, headline)

        items.append(
            {
                "id": _id,
                "datetime": dt.isoformat() if dt else None,
                "source": source,
                "headline": headline,
                "ticker": ticker,
                "sector": sector,
                "country": country,
                "url": url,
                "language": language,
            }
        )
    return items

def guess_last_page(html: str) -> Optional[int]:
    soup = BeautifulSoup(html, "html.parser")
    pag_links = soup.select("div.flex.items-center.gap-2 a")
    nums = []
    for a in pag_links:
        txt = (a.get_text() or "").strip()
        if txt.isdigit():
            nums.append(int(txt))
    return max(nums) if nums else None

# ---------------- Scraper por empresa ----------------
def scrape_company(
    link_news: str,
    ticker_orig: str,
    sector: str,
    company_label: str,
    polite_sleep: float = 0.7,
    max_pages: Optional[int] = DEFAULT_MAX_PAGES,
    save_html_debug: bool = False,
    html_debug_dir: Path = Path("./_html_debug"),
) -> List[Dict]:
    url_base = normalize_news_url(link_news)
    if not url_base:
        log.warning(f"[{company_label}] Link News vazio.")
        return []

    first_url = page_url(url_base, 1)
    r1 = fetch(first_url)
    if not r1:
        log.warning(f"[{company_label}] Não foi possível carregar a página 1: {first_url}")
        return []

    if save_html_debug:
        html_debug_dump(r1.text, company_label, 1, html_debug_dir)

    items = parse_news_items(r1.text, ticker_orig, sector)
    log.info(f"[{company_label}] p1: {len(items)} items.")

    last_page = guess_last_page(r1.text)
    if last_page is None:
        # fallback: iterar enquanto vier notícia (parando após X vazias seguidas)
        page = 2
        empty_streak = 0
        while True:
            if max_pages and page > max_pages:
                log.info(f"[{company_label}] max_pages atingido ({max_pages}).")
                break

            url = page_url(url_base, page)
            time.sleep(polite_sleep)
            r = fetch(url)
            if not r:
                empty_streak += 1
                log.debug(f"[{company_label}] página {page} falhou ({empty_streak} vazias).")
                if empty_streak >= 3:
                    log.info(f"[{company_label}] 3 páginas vazias seguidas; encerrando.")
                    break
                page += 1
                continue

            if save_html_debug:
                html_debug_dump(r.text, company_label, page, html_debug_dir)

            chunk = parse_news_items(r.text, ticker_orig, sector)
            log.info(f"[{company_label}] p{page}: {len(chunk)} items.")
            if not chunk:
                empty_streak += 1
                if empty_streak >= 3:
                    log.info(f"[{company_label}] 3 páginas sem itens; encerrando.")
                    break
            else:
                items.extend(chunk)
                empty_streak = 0
            page += 1
    else:
        total_pages = last_page
        if max_pages:
            total_pages = min(total_pages, max_pages)
        for page in range(2, total_pages + 1):
            url = page_url(url_base, page)
            time.sleep(polite_sleep)
            r = fetch(url)
            if not r:
                log.debug(f"[{company_label}] Falha ao carregar p{page}.")
                continue

            if save_html_debug:
                html_debug_dump(r.text, company_label, page, html_debug_dir)

            chunk = parse_news_items(r.text, ticker_orig, sector)
            log.info(f"[{company_label}] p{page}: {len(chunk)} items.")
            items.extend(chunk)

    return items

# ---------------- Execução principal ----------------
def read_excel(excel_path: Path) -> pd.DataFrame:
    df = pd.read_excel(excel_path)
    expected_cols = {
        "Empresa", "Setor", "Ticker BDR", "Ticker Original (EUA)", "Bolsa (EUA)", "Link News",
    }
    missing = expected_cols - set(df.columns)
    if missing:
        raise ValueError(f"Colunas faltantes no Excel: {sorted(missing)}")
    return df

def merge_incremental(df_new: pd.DataFrame, out_parquet: Path) -> pd.DataFrame:
    if out_parquet.exists():
        df_old = pd.read_parquet(out_parquet)
        df_all = pd.concat([df_old, df_new], ignore_index=True)
        df_all = df_all.drop_duplicates(subset=["id"]).reset_index(drop=True)
        return df_all
    return df_new

def sort_by_datetime(df: pd.DataFrame) -> pd.DataFrame:
    def _safe_parse_iso(x):
        try:
            return du.parse(x)
        except Exception:
            return None
    if "datetime" in df.columns:
        df["_dt_sort"] = df["datetime"].map(_safe_parse_iso)
        df = df.sort_values("_dt_sort", ascending=False).drop(columns=["_dt_sort"])
    return df

def run(
    excel: Path,
    out_parquet: Path,
    only: Optional[str],
    max_pages: Optional[int],
    save_html_debug: bool,
    workers: int,
):
    df_ref = read_excel(excel)
    if only:
        mask = (
            df_ref["Ticker Original (EUA)"].astype(str).str.contains(only, case=False, na=False) |
            df_ref["Empresa"].astype(str).str.contains(only, case=False, na=False)
        )
        df_ref = df_ref[mask].copy()
        log.info(f"Filtrando --only '{only}'. {len(df_ref)} linha(s) no Excel após filtro.")

    backup_dir = Path("./backup")
    backup_dir.mkdir(exist_ok=True)
    log.info(f"Diretório de backup individual: {backup_dir.resolve()}")

    for _, row in tqdm(df_ref.iterrows(), total=len(df_ref), desc="Empresas"):
        empresa = str(row["Empresa"]).strip()
        setor = str(row["Setor"]).strip()
        ticker_orig = str(row["Ticker Original (EUA)"]).strip()
        link_news = str(row["Link News"]).strip()

        if not link_news or link_news.lower() == "nan":
            log.warning(f"[{empresa}] Link News vazio; pulando.")
            continue

        label = ticker_orig or empresa
        items = scrape_company(
            link_news=link_news,
            ticker_orig=ticker_orig or empresa,
            sector=setor,
            company_label=label,
            polite_sleep=0.7,
            max_pages=max_pages if max_pages is not None else DEFAULT_MAX_PAGES,
            save_html_debug=save_html_debug,
        )
        if not items:
            log.info(f"[{label}] Nenhuma notícia nova encontrada.")
            continue

        df_company = pd.DataFrame(items).drop_duplicates(subset=["id"]).reset_index(drop=True)

        backup_filename = f"{safe_filename(label)}.parquet"
        backup_filepath = backup_dir / backup_filename
        df_company.to_parquet(backup_filepath, index=False)
        log.info(f"[{label}] Backup individual com {len(df_company)} notícias salvo em: {backup_filepath}")

        df_merged = merge_incremental(df_company, out_parquet)
        df_merged = sort_by_datetime(df_merged)
        df_merged.to_parquet(out_parquet, index=False)
        log.info(f"[{label}] Salvo. O arquivo principal agora tem {len(df_merged):,} linhas em {out_parquet}")

    log.info("Processo concluído.")
    if not out_parquet.exists():
         log.warning("Nenhuma notícia foi coletada e o arquivo de saída não foi criado.")

# ---------------- CLI ----------------
def parse_args():
    p = argparse.ArgumentParser(description="Scraper de notícias do Investing.com (PT-BR)")
    p.add_argument("--excel", default=DEFAULT_EXCEL, help="Caminho do Excel de referência")
    p.add_argument("--out", default=DEFAULT_OUT, help="Arquivo Parquet de saída")
    p.add_argument("--only", default=None, help="Filtra por Ticker Original (EUA) ou Empresa")
    p.add_argument("--max-pages", type=int, default=DEFAULT_MAX_PAGES, help="Limite máx. de páginas por ativo")
    p.add_argument("--save-html-debug", action="store_true", help="Salva HTML das páginas em ./_html_debug")
    p.add_argument("--workers", type=int, default=1, help="(reservado) Nº de workers em paralelo")
    p.add_argument("--verbose", action="store_true", help="Logs detalhados (DEBUG)")
    p.add_argument("--debug", action="store_true", help="Equivalente a --verbose")
    args, _unknown = p.parse_known_args()
    return args

def main():
    import sys
    if any("ipykernel" in x for x in sys.argv):
        pass
    args = parse_args()
    setup_logging(verbose=args.verbose or args.debug, debug=args.debug)
    excel = Path(args.excel)
    out_parquet = Path(args.out)
    log.info(f"Excel: {excel.resolve()}")
    log.info(f"Saída: {out_parquet.resolve()}")
    if args.only:
        log.info(f"Filtro --only: {args.only}")
    log.info(f"Limite de páginas: {args.max_pages}")
    if args.save_html_debug:
        log.info("Salvar HTML debug: ON")
    try:
        run(
            excel=excel,
            out_parquet=out_parquet,
            only=args.only,
            max_pages=args.max_pages,
            save_html_debug=args.save_html_debug,
            workers=args.workers,
        )
    except Exception as e:
        log.exception(f"Falha fatal: {e}")

if __name__ == "__main__":
    main()
# Out:
# 12:57:49 | INFO    | Excel: /Users/emanuelgandra/Desktop/Projetos /TesteQuant/QuantumSpreadHunters---Quantamental/data/BaseRefAtivos.xlsx
# 12:57:49 | INFO    | Saída: /Users/emanuelgandra/Desktop/Projetos /TesteQuant/QuantumSpreadHunters---Quantamental/data/investing_news.parquet
# 12:57:49 | INFO    | Limite de páginas: 1400
# 12:57:49 | INFO    | Diretório de backup individual: /Users/emanuelgandra/Desktop/Projetos /TesteQuant/QuantumSpreadHunters---Quantamental/notebooks/backup
# Empresas:   0%|          | 0/43 [00:00<?, ?it/s]12:57:50 | INFO    | [AAPL] p1: 10 items.
# 12:57:52 | INFO    | [AAPL] p2: 10 items.
# 12:57:54 | INFO    | [AAPL] p3: 10 items.
# 12:57:56 | INFO    | [AAPL] p4: 10 items.
# 12:57:57 | INFO    | [AAPL] p5: 10 items.
# 12:57:59 | INFO    | [AAPL] p6: 10 items.
# 12:58:01 | INFO    | [AAPL] p7: 10 items.
# 12:58:03 | INFO    | [AAPL] p8: 10 items.
# 12:58:05 | INFO    | [AAPL] p9: 10 items.
# 12:58:07 | INFO    | [AAPL] p10: 10 items.
# 12:58:09 | INFO    | [AAPL] p11: 10 items.
# 12:58:11 | INFO    | [AAPL] p12: 10 items.
# 4       cfd3cde0-5790-5c89-9cbc-059573e6558c  2025-10-17T21:40:21-03:00
# ...                                      ...                        ...
# 137826  59410706-7745-5fdf-a621-795f3e99b47a  2008-11-09T15:12:07-02:00
# 137827  4efd2681-1b83-5391-b534-2c71713fa603  2008-10-30T10:54:07-02:00
# 137828  e4b36c45-4e67-5f8b-a0c9-313f54e1d6a5  2008-10-29T10:54:19-02:00
# 137829  52185042-a9c5-5882-a5ef-374e39a5f031  2008-10-29T10:40:42-02:00
# 137830  be1a4a89-db6b-5762-a0e6-2ed9c9739ac2  2008-10-15T17:14:11-03:00
#
#                source                                           headline  \
# 0             Reuters  Trump approves expanding credits for US auto p...
# 1       Investing.com  Salesforce CEO Benioff sells $558,809 in CRM s...
# 2             Reuters  Boeing can hike 737 MAX production to 42 plane...
# 3             Reuters  Novo Nordisk hires US pharma veteran as Trump ...
# 4       Investing.com  Boeing stock rises after FAA reportedly approv...
# ...               ...                                                ...
# 137826        Reuters  RPT-Wall St Wk Ahead: Stocks eye retail data, ...
# 137827        Reuters  Fairtrade coffee sales steady in economic down...
# 137828        Reuters  China vows harsh penalties for melamine eggs s...
# 137829        Reuters     FACTBOX-Industry bailouts agreed or called for
# 137830        Reuters  GLOBAL MARKETS-Global stocks slide, gold rises...
#
#        ticker        sector country  \
# 0           F    Automotivo
# 1         CRM    Tecnologia
# 2          BA  Aeroespacial
# 3         PFE  Farmacêutica
# 4          BA  Aeroespacial
# ...       ...           ...     ...
# 137826    WMT        Varejo
# 137827   SBUX   Alimentício
# 137828    WMT        Varejo
# 137829      F    Automotivo
# 137830    WMT        Varejo
#
#                                                       url language
# 0       https://www.investing.com/news/stock-market-ne...
# 1       https://www.investing.com/news/insider-trading...
# 2       https://www.investing.com/news/stock-market-ne...
# 3       https://www.investing.com/news/stock-market-ne...
# 4       https://www.investing.com/news/stock-market-ne...
# ...                                                   ...      ...
# 137826  https://www.investing.com/news/forex-news/rpt-...
# 137827  https://www.investing.com/news/forex-news/fair...
# 137828  https://www.investing.com/news/forex-news/chin...
# 137829  https://www.investing.com/news/forex-news/fact...
# 137830  https://www.investing.com/news/forex-news/glob...
#
# [137831 rows x 9 columns]

# %%
from __future__ import annotations
import re
import time
import uuid
import os
import random
import argparse
from pathlib import Path
from typing import Optional, List, Dict
from datetime import datetime, timedelta
from zoneinfo import ZoneInfo

import pandas as pd
import requests
from bs4 import BeautifulSoup
from dateutil import parser as du
from tqdm import tqdm
import logging

# ---------------- Config & Globals ----------------
SP_TZ = ZoneInfo("America/Sao_Paulo")

DEFAULT_EXCEL = "../data/BaseRefAtivosNacionais.xlsx"
DEFAULT_OUT = "../data/investing_news_nacionais.parquet"
DEFAULT_MAX_PAGES = 1400

HEADERS = {
    "User-Agent": (
        "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
        "AppleWebKit/537.36 (KHTML, like Gecko) "
        "Chrome/127.0.0.0 Safari/537.36"
    ),
    "Accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7",
    "Accept-Language": "pt-BR,pt;q=0.9,en-US;q=0.8,en;q=0.7",
    "Referer": "https://br.investing.com/",
    "DNT": "1",
    "Upgrade-Insecure-Requests": "1",
    "Sec-Fetch-Dest": "document",
    "Sec-Fetch-Mode": "navigate",
}

SESSION = requests.Session()
SESSION.headers.update(HEADERS)

RELATIVE_REGEX = re.compile(
    r"(?P<num>\d+)\s*(?P<unit>min|mins|minutos|minuto|hora|horas|dia|dias)\s*atr[aá]s",
    flags=re.IGNORECASE,
)

# ---------------- Logging ----------------
def setup_logging(verbose: bool = False, debug: bool = False) -> None:
    level = logging.INFO
    if verbose or debug:
        level = logging.DEBUG
    logging.basicConfig(
        level=level,
        format="%(asctime)s | %(levelname)-7s | %(message)s",
        datefmt="%H:%M:%S",
    )

log = logging.getLogger(__name__)

# ---------------- Utils ----------------
def normalize_news_url(url: str) -> str:
    """Garante base ...-news e remove sufixo /<n> para paginar manualmente."""
    url = (url or "").strip()
    if not url:
        return url
    if url.endswith("-new"):
        url = url + "s"
    url = re.sub(r"/+$", "", url)
    m = re.search(r"/(\d+)$", url)
    if m:
        url = url[: - (len(m.group(0)))]
    return url

def page_url(url_base: str, page: int) -> str:
    return f"{url_base}/{page}"

def parse_datetime_from_time_tag(time_tag) -> Optional[datetime]:
    if time_tag is None:
        return None

    text = (time_tag.get_text() or "").strip().lower()
    m = RELATIVE_REGEX.search(text)
    if m:
        num = int(m.group("num"))
        unit = m.group("unit")
        now_sp = datetime.now(SP_TZ)

        if unit.startswith("min"):
            dt = now_sp - timedelta(minutes=num)
        elif unit.startswith("hora"):
            dt = now_sp - timedelta(hours=num)
        else:
            dt = now_sp - timedelta(days=num)
        return dt

    dt_attr = time_tag.get("datetime")
    if dt_attr:
        try:
            dt = du.parse(dt_attr)
            if dt.tzinfo is None:
                dt = dt.replace(tzinfo=SP_TZ)
            return dt.astimezone(SP_TZ)
        except Exception as e:
            log.debug(f"Falha parse datetime attr '{dt_attr}': {e}")

    try:
        dt = du.parse(text, dayfirst=True, fuzzy=True, languages=["pt"])
        if dt is not None:
            if dt.tzinfo is None:
                dt = dt.replace(tzinfo=SP_TZ)
            return dt.astimezone(SP_TZ)
    except Exception as e:
        log.debug(f"Falha parse texto de data '{text}': {e}")

    return None

def deduce_country_language_from_url(url: str) -> tuple[str, str]:
    if "br.investing.com" in url:
        return ("BR", "pt-BR")
    return ("", "")

def make_news_id(url: str, title: str) -> str:
    base = (url or "").strip() + "||" + (title or "").strip()
    return str(uuid.uuid5(uuid.NAMESPACE_URL, base))

def html_debug_dump(html: str, company: str, page: int, outdir: Path) -> None:
    outdir.mkdir(parents=True, exist_ok=True)
    fn = outdir / f"{safe_filename(company)}_p{page:04d}.html"
    try:
        fn.write_text(html, encoding="utf-8")
        log.debug(f"HTML salvo para debug: {fn}")
    except Exception as e:
        log.warning(f"Falha ao salvar HTML de debug: {e}")

def safe_filename(s: str) -> str:
    return re.sub(r"[^A-Za-z0-9._-]+", "_", s.strip())

# ---------------- HTTP com backoff ----------------
def fetch(url: str, max_retries: int = 5, timeout: int = 25) -> Optional[requests.Response]:
    for i in range(max_retries):
        try:
            r = SESSION.get(url, timeout=timeout)
            if r.status_code == 200:
                return r
            if r.status_code in (404, 410):
                log.info(f"HTTP {r.status_code} em {url} (provável fim).")
                return None
            if r.status_code in (429, 500, 502, 503, 504):
                wait = (1.5 * (i + 1)) + random.random()
                log.warning(f"HTTP {r.status_code} em {url}; retry em {wait:.1f}s")
                time.sleep(wait)
                continue
            log.warning(f"HTTP {r.status_code} em {url}; sem retry programado.")
            return None
        except requests.RequestException as e:
            wait = (1.2 * (i + 1)) + random.random()
            log.warning(f"Erro rede: {e}; retry em {wait:.1f}s")
            time.sleep(wait)
    log.error(f"Falhou após {max_retries} tentativas: {url}")
    return None

# ---------------- Parsing ----------------
def parse_news_items(html: str, ticker: str, sector: str) -> List[Dict]:
    soup = BeautifulSoup(html, "html.parser")
    ul = soup.find("ul", attrs={"data-test": "news-list"})
    if not ul:
        log.debug("Ul[data-test='news-list'] não encontrada — página pode ter mudado.")
        return []

    items: List[Dict] = []
    arts = ul.select("article[data-test='article-item']")
    if not arts:
        log.debug("Nenhum article[data-test='article-item'] encontrado nesta página.")
        return []

    for art in arts:
        a_title = art.select_one("a[data-test='article-title-link']")
        if not a_title:
            log.debug("a[data-test='article-title-link'] ausente em um article; pulando.")
            continue

        headline = (a_title.get_text() or "").strip()
        url = a_title.get("href") or ""
        if url.startswith("/"):
            url = "https://br.investing.com" + url

        a_provider = art.select_one("a[data-test='article-provider-link']")
        source = (a_provider.get_text().strip() if a_provider else "").strip()

        t = art.select_one("time[data-test='article-publish-date']")
        dt = parse_datetime_from_time_tag(t)

        country, language = deduce_country_language_from_url(url)
        _id = make_news_id(url, headline)

        items.append(
            {
                "id": _id,
                "datetime": dt.isoformat() if dt else None,
                "source": source,
                "headline": headline,
                "ticker": ticker,
                "sector": sector,
                "country": country,
                "url": url,
                "language": language,
            }
        )
    return items

def guess_last_page(html: str) -> Optional[int]:
    soup = BeautifulSoup(html, "html.parser")
    pag_links = soup.select("div.flex.items-center.gap-2 a")
    nums = []
    for a in pag_links:
        txt = (a.get_text() or "").strip()
        if txt.isdigit():
            nums.append(int(txt))
    return max(nums) if nums else None

# ---------------- Scraper por empresa ----------------
def scrape_company(
    link_news: str,
    ticker_orig: str,
    sector: str,
    company_label: str,
    polite_sleep: float = 0.7,
    max_pages: Optional[int] = DEFAULT_MAX_PAGES,
    save_html_debug: bool = False,
    html_debug_dir: Path = Path("./_html_debug"),
) -> List[Dict]:
    url_base = normalize_news_url(link_news)
    if not url_base:
        log.warning(f"[{company_label}] Link News vazio.")
        return []

    first_url = page_url(url_base, 1)
    r1 = fetch(first_url)
    if not r1:
        log.warning(f"[{company_label}] Não foi possível carregar a página 1: {first_url}")
        return []

    if save_html_debug:
        html_debug_dump(r1.text, company_label, 1, html_debug_dir)

    items = parse_news_items(r1.text, ticker_orig, sector)
    log.info(f"[{company_label}] p1: {len(items)} items.")

    last_page = guess_last_page(r1.text)
    if last_page is None:
        # fallback: iterar enquanto vier notícia (parando após X vazias seguidas)
        page = 2
        empty_streak = 0
        while True:
            if max_pages and page > max_pages:
                log.info(f"[{company_label}] max_pages atingido ({max_pages}).")
                break

            url = page_url(url_base, page)
            time.sleep(polite_sleep)
            r = fetch(url)
            if not r:
                empty_streak += 1
                log.debug(f"[{company_label}] página {page} falhou ({empty_streak} vazias).")
                if empty_streak >= 3:
                    log.info(f"[{company_label}] 3 páginas vazias seguidas; encerrando.")
                    break
                page += 1
                continue

            if save_html_debug:
                html_debug_dump(r.text, company_label, page, html_debug_dir)

            chunk = parse_news_items(r.text, ticker_orig, sector)
            log.info(f"[{company_label}] p{page}: {len(chunk)} items.")
            if not chunk:
                empty_streak += 1
                if empty_streak >= 3:
                    log.info(f"[{company_label}] 3 páginas sem itens; encerrando.")
                    break
            else:
                items.extend(chunk)
                empty_streak = 0
            page += 1
    else:
        total_pages = last_page
        if max_pages:
            total_pages = min(total_pages, max_pages)
        for page in range(2, total_pages + 1):
            url = page_url(url_base, page)
            time.sleep(polite_sleep)
            r = fetch(url)
            if not r:
                log.debug(f"[{company_label}] Falha ao carregar p{page}.")
                continue

            if save_html_debug:
                html_debug_dump(r.text, company_label, page, html_debug_dir)

            chunk = parse_news_items(r.text, ticker_orig, sector)
            log.info(f"[{company_label}] p{page}: {len(chunk)} items.")
            items.extend(chunk)

    return items

# ---------------- Execução principal ----------------
def read_excel(excel_path: Path) -> pd.DataFrame:
    df = pd.read_excel(excel_path)
    # ATUALIZADO: Verifica as colunas do novo formato para ativos nacionais
    expected_cols = {
        "Empresa", "Setor", "Ticker B3", "Ticker ADR", "Bolsa (EUA)", "Link News",
    }
    missing = expected_cols - set(df.columns)
    if missing:
        raise ValueError(f"Colunas faltantes no Excel: {sorted(missing)}")
    return df

def merge_incremental(df_new: pd.DataFrame, out_parquet: Path) -> pd.DataFrame:
    if out_parquet.exists():
        df_old = pd.read_parquet(out_parquet)
        df_all = pd.concat([df_old, df_new], ignore_index=True)
        df_all = df_all.drop_duplicates(subset=["id"]).reset_index(drop=True)
        return df_all
    return df_new

def sort_by_datetime(df: pd.DataFrame) -> pd.DataFrame:
    def _safe_parse_iso(x):
        try:
            return du.parse(x)
        except Exception:
            return None
    if "datetime" in df.columns:
        df["_dt_sort"] = df["datetime"].map(_safe_parse_iso)
        df = df.sort_values("_dt_sort", ascending=False).drop(columns=["_dt_sort"])
    return df

def run(
    excel: Path,
    out_parquet: Path,
    only: Optional[str],
    max_pages: Optional[int],
    save_html_debug: bool,
    workers: int,
):
    df_ref = read_excel(excel)
    if only:
        # ATUALIZADO: Filtra usando a coluna 'Ticker B3'
        mask = (
            df_ref["Ticker B3"].astype(str).str.contains(only, case=False, na=False) |
            df_ref["Empresa"].astype(str).str.contains(only, case=False, na=False)
        )
        df_ref = df_ref[mask].copy()
        log.info(f"Filtrando --only '{only}'. {len(df_ref)} linha(s) no Excel após filtro.")

    backup_dir = Path("./backup")
    backup_dir.mkdir(exist_ok=True)
    log.info(f"Diretório de backup individual: {backup_dir.resolve()}")

    for _, row in tqdm(df_ref.iterrows(), total=len(df_ref), desc="Empresas"):
        empresa = str(row["Empresa"]).strip()
        setor = str(row["Setor"]).strip()
        # ATUALIZADO: Pega o ticker da coluna 'Ticker B3'
        ticker_orig = str(row["Ticker B3"]).strip()
        link_news = str(row["Link News"]).strip()

        if not link_news or link_news.lower() == "nan":
            log.warning(f"[{empresa}] Link News vazio; pulando.")
            continue

        label = ticker_orig or empresa
        items = scrape_company(
            link_news=link_news,
            ticker_orig=ticker_orig or empresa,
            sector=setor,
            company_label=label,
            polite_sleep=0.7,
            max_pages=max_pages if max_pages is not None else DEFAULT_MAX_PAGES,
            save_html_debug=save_html_debug,
        )
        if not items:
            log.info(f"[{label}] Nenhuma notícia nova encontrada.")
            continue

        df_company = pd.DataFrame(items).drop_duplicates(subset=["id"]).reset_index(drop=True)

        backup_filename = f"{safe_filename(label)}.parquet"
        backup_filepath = backup_dir / backup_filename
        df_company.to_parquet(backup_filepath, index=False)
        log.info(f"[{label}] Backup individual com {len(df_company)} notícias salvo em: {backup_filepath}")

        df_merged = merge_incremental(df_company, out_parquet)
        df_merged = sort_by_datetime(df_merged)
        df_merged.to_parquet(out_parquet, index=False)
        log.info(f"[{label}] Salvo. O arquivo principal agora tem {len(df_merged):,} linhas em {out_parquet}")

    log.info("Processo concluído.")
    if not out_parquet.exists():
         log.warning("Nenhuma notícia foi coletada e o arquivo de saída não foi criado.")

# ---------------- CLI ----------------
def parse_args():
    p = argparse.ArgumentParser(description="Scraper de notícias do Investing.com (PT-BR)")
    p.add_argument("--excel", default=DEFAULT_EXCEL, help="Caminho do Excel de referência")
    p.add_argument("--out", default=DEFAULT_OUT, help="Arquivo Parquet de saída")
    # ATUALIZADO: Ajuda reflete a mudança para Ticker B3
    p.add_argument("--only", default=None, help="Filtra por Ticker B3 ou Empresa")
    p.add_argument("--max-pages", type=int, default=DEFAULT_MAX_PAGES, help="Limite máx. de páginas por ativo")
    p.add_argument("--save-html-debug", action="store_true", help="Salva HTML das páginas em ./_html_debug")
    p.add_argument("--workers", type=int, default=1, help="(reservado) Nº de workers em paralelo")
    p.add_argument("--verbose", action="store_true", help="Logs detalhados (DEBUG)")
    p.add_argument("--debug", action="store_true", help="Equivalente a --verbose")
    args, _unknown = p.parse_known_args()
    return args

def main():
    import sys
    if any("ipykernel" in x for x in sys.argv):
        pass
    args = parse_args()
    setup_logging(verbose=args.verbose or args.debug, debug=args.debug)
    excel = Path(args.excel)
    out_parquet = Path(args.out)
    log.info(f"Excel: {excel.resolve()}")
    log.info(f"Saída: {out_parquet.resolve()}")
    if args.only:
        log.info(f"Filtro --only: {args.only}")
    log.info(f"Limite de páginas: {args.max_pages}")
    if args.save_html_debug:
        log.info("Salvar HTML debug: ON")
    try:
        run(
            excel=excel,
            out_parquet=out_parquet,
            only=args.only,
            max_pages=args.max_pages,
            save_html_debug=args.save_html_debug,
            workers=args.workers,
        )
    except Exception as e:
        log.exception(f"Falha fatal: {e}")

if __name__ == "__main__":
    main()
# Out:
# 02:32:34 | INFO    | Excel: /Users/emanuelgandra/Desktop/Projetos /TesteQuant/QuantumSpreadHunters---Quantamental/data/BaseRefAtivosNacionais.xlsx
# 02:32:34 | INFO    | Saída: /Users/emanuelgandra/Desktop/Projetos /TesteQuant/QuantumSpreadHunters---Quantamental/data/investing_news_nacionais.parquet
# 02:32:34 | INFO    | Limite de páginas: 1400
# 02:32:34 | INFO    | Diretório de backup individual: /Users/emanuelgandra/Desktop/Projetos /TesteQuant/QuantumSpreadHunters---Quantamental/notebooks/backup
# Empresas:   0%|          | 0/34 [00:00<?, ?it/s]02:32:36 | INFO    | [VALE3] p1: 10 items.
# 02:32:38 | INFO    | [VALE3] p2: 10 items.
# 02:32:40 | INFO    | [VALE3] p3: 10 items.
# 02:32:42 | INFO    | [VALE3] p4: 10 items.
# 02:32:44 | INFO    | [VALE3] p5: 10 items.
# 02:32:45 | INFO    | [VALE3] p6: 10 items.
# 02:32:47 | INFO    | [VALE3] p7: 10 items.
# 02:59:10 | INFO    | [VALE3] p799: 10 items.
# 02:59:12 | INFO    | [VALE3] p800: 10 items.
# 02:59:14 | INFO    | [VALE3] p801: 10 items.
# 02:59:16 | INFO    | [VALE3] p802: 10 items.
# 02:59:18 | INFO    | [VALE3] p803: 10 items.
# 02:59:20 | INFO    | [VALE3] p804: 10 items.
# 02:59:22 | INFO    | [VALE3] p805: 10 items.
# 02:59:24 | INFO    | [VALE3] p806: 10 items.
# 02:59:26 | INFO    | [VALE3] p807: 10 items.
# 02:59:28 | INFO    | [VALE3] p808: 10 items.
# 02:59:30 | INFO    | [VALE3] p809: 10 items.
# 02:59:32 | INFO    | [VALE3] p810: 10 items.
# 02:59:34 | INFO    | [VALE3] p811: 10 items.
# 02:59:35 | INFO    | [VALE3] p812: 10 items.
# 02:59:37 | INFO    | [VALE3] p813: 10 items.
# 02:59:39 | INFO    | [VALE3] p814: 10 items.
# 02:59:41 | INFO    | [VALE3] p815: 10 items.
# 02:59:42 | INFO    | [VALE3] p816: 10 items.
# 02:59:45 | INFO    | [VALE3] p817: 10 items.
# 02:59:46 | INFO    | [VALE3] p818: 10 items.
# 02:59:48 | INFO    | [VALE3] p819: 10 items.
# 02:59:50 | INFO    | [VALE3] p820: 10 items.
# 02:59:51 | INFO    | [VALE3] p821: 10 items.
# 02:59:53 | INFO    | [VALE3] p822: 10 items.
# 02:59:55 | INFO    | [VALE3] p823: 10 items.
# 02:59:57 | INFO    | [VALE3] p824: 10 items.
# 02:59:59 | INFO    | [VALE3] p825: 10 items.
# 03:00:01 | INFO    | [VALE3] p826: 10 items.
# 03:00:03 | INFO    | [VALE3] p827: 10 items.
# 03:00:04 | INFO    | [VALE3] p828: 10 items.
# 03:00:06 | INFO    | [VALE3] p829: 10 items.
# 03:00:08 | INFO    | [VALE3] p830: 10 items.
# 03:00:10 | INFO    | [VALE3] p831: 10 items.
# 03:00:12 | INFO    | [VALE3] p832: 10 items.
# 03:00:14 | INFO    | [VALE3] p833: 10 items.
# 03:00:16 | INFO    | [VALE3] p834: 10 items.
# 03:00:18 | INFO    | [VALE3] p835: 10 items.
# 03:00:19 | INFO    | [VALE3] p836: 10 items.
# 03:00:21 | INFO    | [VALE3] p837: 10 items.
# 03:00:23 | INFO    | [VALE3] p838: 10 items.
# 03:00:25 | INFO    | [VALE3] p839: 10 items.
# 03:00:27 | INFO    | [VALE3] p840: 10 items.
# 03:00:29 | INFO    | [VALE3] p841: 10 items.
# 03:00:31 | INFO    | [VALE3] p842: 10 items.
# 03:00:32 | INFO    | [VALE3] p843: 10 items.
# 03:00:34 | INFO    | [VALE3] p844: 10 items.
# 03:00:36 | INFO    | [VALE3] p845: 10 items.
# 03:00:38 | INFO    | [VALE3] p846: 10 items.
# 03:00:40 | INFO    | [VALE3] p847: 10 items.
# 03:00:41 | INFO    | [VALE3] p848: 10 items.
# 03:00:43 | INFO    | [VALE3] p849: 10 items.
# 03:00:45 | INFO    | [VALE3] p850: 10 items.
# 03:00:47 | INFO    | [VALE3] p851: 10 items.
# 03:00:49 | INFO    | [VALE3] p852: 10 items.
# 03:00:51 | INFO    | [VALE3] p853: 10 items.
# 03:00:53 | INFO    | [VALE3] p854: 10 items.
# 03:00:55 | INFO    | [VALE3] p855: 10 items.
# 03:00:56 | INFO    | [VALE3] p856: 10 items.
# 03:00:58 | INFO    | [VALE3] p857: 10 items.
# 03:01:00 | INFO    | [VALE3] p858: 10 items.
# 03:01:02 | INFO    | [VALE3] p859: 10 items.
# 03:01:04 | INFO    | [VALE3] p860: 10 items.
# 03:01:06 | INFO    | [VALE3] p861: 10 items.
# 03:01:07 | INFO    | [VALE3] p862: 10 items.
# 03:01:10 | INFO    | [VALE3] p863: 10 items.
# 03:01:12 | INFO    | [VALE3] p864: 10 items.
# 03:01:13 | INFO    | [VALE3] p865: 10 items.
# 03:01:15 | INFO    | [VALE3] p866: 10 items.
# 03:01:18 | INFO    | [VALE3] p867: 10 items.
# 03:01:20 | INFO    | [VALE3] p868: 10 items.
# 03:01:21 | INFO    | [VALE3] p869: 10 items.
# 03:01:23 | INFO    | [VALE3] p870: 10 items.
# 03:01:25 | INFO    | [VALE3] p871: 10 items.
# 03:01:27 | INFO    | [VALE3] p872: 10 items.
# 03:01:29 | INFO    | [VALE3] p873: 10 items.
# 03:01:30 | INFO    | [VALE3] p874: 10 items.
# 03:01:32 | INFO    | [VALE3] p875: 10 items.
# 03:01:34 | INFO    | [VALE3] p876: 10 items.
# 03:01:36 | INFO    | [VALE3] p877: 10 items.
# 03:01:38 | INFO    | [VALE3] p878: 10 items.
# 03:01:39 | INFO    | [VALE3] p879: 10 items.
# 03:01:41 | INFO    | [VALE3] p880: 10 items.
# 03:01:43 | INFO    | [VALE3] p881: 10 items.
# 03:01:45 | INFO    | [VALE3] p882: 10 items.
# 03:01:47 | INFO    | [VALE3] p883: 10 items.
# 03:01:49 | INFO    | [VALE3] p884: 10 items.
# 03:01:51 | INFO    | [VALE3] p885: 10 items.
# 03:01:53 | INFO    | [VALE3] p886: 10 items.
# 03:01:54 | INFO    | [VALE3] p887: 10 items.
# 03:01:56 | INFO    | [VALE3] p888: 10 items.
# 03:01:58 | INFO    | [VALE3] p889: 10 items.
# 03:02:00 | INFO    | [VALE3] p890: 10 items.
# 03:02:02 | INFO    | [VALE3] p891: 10 items.
# 03:02:04 | INFO    | [VALE3] p892: 10 items.
# 03:02:05 | INFO    | [VALE3] p893: 10 items.
# 03:02:07 | INFO    | [VALE3] p894: 10 items.
# 03:02:09 | INFO    | [VALE3] p895: 10 items.
# 03:02:11 | INFO    | [VALE3] p896: 10 items.
# 03:02:13 | INFO    | [VALE3] p897: 10 items.
# 03:02:15 | INFO    | [VALE3] p898: 10 items.
# 03:02:16 | INFO    | [VALE3] p899: 10 items.
# 03:02:18 | INFO    | [VALE3] p900: 10 items.
# 03:02:20 | INFO    | [VALE3] p901: 10 items.
# 03:02:23 | INFO    | [VALE3] p902: 10 items.
# 03:02:25 | INFO    | [VALE3] p903: 10 items.
# 03:02:27 | INFO    | [VALE3] p904: 10 items.
# 03:02:30 | INFO    | [VALE3] p905: 10 items.
# 03:02:32 | INFO    | [VALE3] p906: 10 items.
# 03:02:34 | INFO    | [VALE3] p907: 10 items.
# 03:02:35 | INFO    | [VALE3] p908: 10 items.
# 03:02:37 | INFO    | [VALE3] p909: 10 items.
# 03:02:39 | INFO    | [VALE3] p910: 10 items.
# 03:02:41 | INFO    | [VALE3] p911: 10 items.
# 03:02:42 | INFO    | [VALE3] p912: 10 items.
# 03:02:44 | INFO    | [VALE3] p913: 10 items.
# 03:02:46 | INFO    | [VALE3] p914: 10 items.
# 03:02:48 | INFO    | [VALE3] p915: 10 items.
# 03:02:49 | INFO    | [VALE3] p916: 10 items.
# 03:02:51 | INFO    | [VALE3] p917: 10 items.
# 03:02:53 | INFO    | [VALE3] p918: 10 items.
# 03:02:55 | INFO    | [VALE3] p919: 10 items.
# 03:02:56 | INFO    | [VALE3] p920: 10 items.
# 03:02:58 | INFO    | [VALE3] p921: 10 items.
# 03:03:00 | INFO    | [VALE3] p922: 10 items.
# 03:03:02 | INFO    | [VALE3] p923: 10 items.
# 03:03:04 | INFO    | [VALE3] p924: 10 items.
# 03:03:05 | INFO    | [VALE3] p925: 10 items.
# 03:03:08 | INFO    | [VALE3] p926: 10 items.
# 03:03:09 | INFO    | [VALE3] p927: 10 items.
# 03:03:11 | INFO    | [VALE3] p928: 10 items.
# 03:03:13 | INFO    | [VALE3] p929: 10 items.
# 03:03:15 | INFO    | [VALE3] p930: 10 items.
# 03:03:17 | INFO    | [VALE3] p931: 10 items.
# 03:03:19 | INFO    | [VALE3] p932: 10 items.
# 03:03:21 | INFO    | [VALE3] p933: 10 items.
# 03:03:23 | INFO    | [VALE3] p934: 10 items.
# 03:03:25 | INFO    | [VALE3] p935: 10 items.
# 03:03:27 | INFO    | [VALE3] p936: 10 items.
# 03:03:29 | INFO    | [VALE3] p937: 10 items.
# 03:03:31 | INFO    | [VALE3] p938: 10 items.
# 03:03:32 | INFO    | [VALE3] p939: 10 items.
# 03:03:34 | INFO    | [VALE3] p940: 10 items.
# 03:03:36 | INFO    | [VALE3] p941: 10 items.
# 03:03:38 | INFO    | [VALE3] p942: 10 items.
# 03:03:39 | INFO    | [VALE3] p943: 10 items.
# 03:03:41 | INFO    | [VALE3] p944: 10 items.
# 03:03:43 | INFO    | [VALE3] p945: 10 items.
# 03:03:45 | INFO    | [VALE3] p946: 10 items.
# 03:03:47 | INFO    | [VALE3] p947: 10 items.
# 03:03:49 | INFO    | [VALE3] p948: 10 items.
# 03:03:50 | INFO    | [VALE3] p949: 10 items.
# 03:03:52 | INFO    | [VALE3] p950: 10 items.
# 03:03:54 | INFO    | [VALE3] p951: 10 items.
# 03:03:56 | INFO    | [VALE3] p952: 10 items.
# 03:03:57 | INFO    | [VALE3] p953: 10 items.
# 03:03:59 | INFO    | [VALE3] p954: 10 items.
# 03:04:01 | INFO    | [VALE3] p955: 10 items.
# 03:04:03 | INFO    | [VALE3] p956: 10 items.
# 03:04:05 | INFO    | [VALE3] p957: 10 items.
# 03:04:07 | INFO    | [VALE3] p958: 10 items.
# 03:04:08 | INFO    | [VALE3] p959: 10 items.
# 03:04:10 | INFO    | [VALE3] p960: 10 items.
# 03:04:12 | INFO    | [VALE3] p961: 10 items.
# 03:04:14 | INFO    | [VALE3] p962: 10 items.
# 03:04:15 | INFO    | [VALE3] p963: 10 items.
# 03:04:17 | INFO    | [VALE3] p964: 10 items.
# 03:04:19 | INFO    | [VALE3] p965: 10 items.
# 03:04:21 | INFO    | [VALE3] p966: 10 items.
# 03:04:23 | INFO    | [VALE3] p967: 10 items.
# 03:04:25 | INFO    | [VALE3] p968: 10 items.
# 03:04:26 | INFO    | [VALE3] p969: 10 items.
# 03:04:28 | INFO    | [VALE3] p970: 10 items.
# 03:04:30 | INFO    | [VALE3] p971: 10 items.
# 03:04:32 | INFO    | [VALE3] p972: 10 items.
# 03:04:33 | INFO    | [VALE3] p973: 10 items.
# 03:04:35 | INFO    | [VALE3] p974: 10 items.
# 03:04:37 | INFO    | [VALE3] p975: 10 items.
# 03:04:39 | INFO    | [VALE3] p976: 10 items.
# 03:04:41 | INFO    | [VALE3] p977: 10 items.
# 03:04:42 | INFO    | [VALE3] p978: 10 items.
# 03:04:44 | INFO    | [VALE3] p979: 10 items.
# 03:04:46 | INFO    | [VALE3] p980: 10 items.
# 03:04:48 | INFO    | [VALE3] p981: 10 items.
# 03:04:49 | INFO    | [VALE3] p982: 10 items.
# 03:04:51 | INFO    | [VALE3] p983: 10 items.
# 03:04:53 | INFO    | [VALE3] p984: 10 items.
# 03:04:55 | INFO    | [VALE3] p985: 10 items.
# 03:04:57 | INFO    | [VALE3] p986: 10 items.
# 03:04:58 | INFO    | [VALE3] p987: 10 items.
# 03:05:00 | INFO    | [VALE3] p988: 10 items.
# 03:05:02 | INFO    | [VALE3] p989: 10 items.
# 03:05:04 | INFO    | [VALE3] p990: 10 items.
# 03:05:06 | INFO    | [VALE3] p991: 10 items.
# 03:05:07 | INFO    | [VALE3] p992: 10 items.
# 03:05:09 | INFO    | [VALE3] p993: 10 items.
# 03:05:11 | INFO    | [VALE3] p994: 10 items.
# 03:05:13 | INFO    | [VALE3] p995: 10 items.
# 03:05:15 | INFO    | [VALE3] p996: 10 items.
# 03:05:17 | INFO    | [VALE3] p997: 10 items.
# 03:05:19 | INFO    | [VALE3] p998: 10 items.
# 03:05:21 | INFO    | [VALE3] p999: 10 items.
# 03:05:23 | INFO    | [VALE3] p1000: 10 items.
# 03:05:23 | INFO    | [VALE3] Backup individual com 9959 notícias salvo em: backup/VALE3.parquet
# 03:05:24 | INFO    | [VALE3] Salvo. O arquivo principal agora tem 17,588 linhas em ../data/investing_news_nacionais.parquet
# Empresas:   3%|▎         | 1/34 [32:49<18:03:14, 1969.52s/it]03:05:25 | INFO    | [PETR3 / PETR4] p1: 10 items.
# 03:05:27 | INFO    | [PETR3 / PETR4] p2: 10 items.
# 03:05:29 | INFO    | [PETR3 / PETR4] p3: 10 items.
# 03:05:31 | INFO    | [PETR3 / PETR4] p4: 10 items.
# Empresas:  91%|█████████ | 31/34 [5:31:43<09:36, 192.26s/it]08:04:19 | INFO    | HTTP 404 em https://br.investing.com/equities/arco-platform-ltd-news/1 (provável fim).
# 08:04:19 | WARNING | [ARCE31] Não foi possível carregar a página 1: https://br.investing.com/equities/arco-platform-ltd-news/1
# 08:04:19 | INFO    | [ARCE31] Nenhuma notícia nova encontrada.
# Empresas:  94%|█████████▍| 32/34 [5:31:44<04:29, 134.85s/it]08:04:20 | INFO    | HTTP 404 em https://br.investing.com/equities/vtex-commerce-cloud-solutions-news/1 (provável fim).
# 08:04:20 | WARNING | [VTEX3] Não foi possível carregar a página 1: https://br.investing.com/equities/vtex-commerce-cloud-solutions-news/1
# 08:04:20 | INFO    | [VTEX3] Nenhuma notícia nova encontrada.
# Empresas:  97%|█████████▋| 33/34 [5:31:45<01:34, 94.72s/it] 08:04:21 | INFO    | HTTP 404 em https://br.investing.com/equities/ciandt-inc-class-a-news/1 (provável fim).
# 08:04:21 | WARNING | [CIET3] Não foi possível carregar a página 1: https://br.investing.com/equities/ciandt-inc-class-a-news/1
# 08:04:21 | INFO    | [CIET3] Nenhuma notícia nova encontrada.
# Empresas: 100%|██████████| 34/34 [5:31:46<00:00, 585.49s/it]
# 08:04:21 | INFO    | Processo concluído.

# %%
from __future__ import annotations
import re
import time
import uuid
import os
import random
import argparse
from pathlib import Path
from typing import Optional, List, Dict
from datetime import datetime, timedelta
from zoneinfo import ZoneInfo

import pandas as pd
import requests
from bs4 import BeautifulSoup
from dateutil import parser as du
from tqdm import tqdm
import logging

# ---------------- Config & Globals ----------------
SP_TZ = ZoneInfo("America/Sao_Paulo")

DEFAULT_EXCEL = "../data/BaseRefAtivosNacionais.xlsx"
DEFAULT_OUT = "../data/investing_news_nacionais_que_faltaram.parquet"
DEFAULT_MAX_PAGES = 1400

HEADERS = {
    "User-Agent": (
        "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
        "AppleWebKit/537.36 (KHTML, like Gecko) "
        "Chrome/127.0.0.0 Safari/537.36"
    ),
    "Accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7",
    "Accept-Language": "pt-BR,pt;q=0.9,en-US;q=0.8,en;q=0.7",
    "Referer": "https://br.investing.com/",
    "DNT": "1",
    "Upgrade-Insecure-Requests": "1",
    "Sec-Fetch-Dest": "document",
    "Sec-Fetch-Mode": "navigate",
}

SESSION = requests.Session()
SESSION.headers.update(HEADERS)

RELATIVE_REGEX = re.compile(
    r"(?P<num>\d+)\s*(?P<unit>min|mins|minutos|minuto|hora|horas|dia|dias)\s*atr[aá]s",
    flags=re.IGNORECASE,
)

# ---------------- Logging ----------------
def setup_logging(verbose: bool = False, debug: bool = False) -> None:
    level = logging.INFO
    if verbose or debug:
        level = logging.DEBUG
    logging.basicConfig(
        level=level,
        format="%(asctime)s | %(levelname)-7s | %(message)s",
        datefmt="%H:%M:%S",
    )

log = logging.getLogger(__name__)

# ---------------- Utils ----------------
def normalize_news_url(url: str) -> str:
    """Garante base ...-news e remove sufixo /<n> para paginar manualmente."""
    url = (url or "").strip()
    if not url:
        return url
    if url.endswith("-new"):
        url = url + "s"
    url = re.sub(r"/+$", "", url)
    m = re.search(r"/(\d+)$", url)
    if m:
        url = url[: - (len(m.group(0)))]
    return url

def page_url(url_base: str, page: int) -> str:
    return f"{url_base}/{page}"

def parse_datetime_from_time_tag(time_tag) -> Optional[datetime]:
    if time_tag is None:
        return None

    text = (time_tag.get_text() or "").strip().lower()
    m = RELATIVE_REGEX.search(text)
    if m:
        num = int(m.group("num"))
        unit = m.group("unit")
        now_sp = datetime.now(SP_TZ)

        if unit.startswith("min"):
            dt = now_sp - timedelta(minutes=num)
        elif unit.startswith("hora"):
            dt = now_sp - timedelta(hours=num)
        else:
            dt = now_sp - timedelta(days=num)
        return dt

    dt_attr = time_tag.get("datetime")
    if dt_attr:
        try:
            dt = du.parse(dt_attr)
            if dt.tzinfo is None:
                dt = dt.replace(tzinfo=SP_TZ)
            return dt.astimezone(SP_TZ)
        except Exception as e:
            log.debug(f"Falha parse datetime attr '{dt_attr}': {e}")

    try:
        dt = du.parse(text, dayfirst=True, fuzzy=True, languages=["pt"])
        if dt is not None:
            if dt.tzinfo is None:
                dt = dt.replace(tzinfo=SP_TZ)
            return dt.astimezone(SP_TZ)
    except Exception as e:
        log.debug(f"Falha parse texto de data '{text}': {e}")

    return None

def deduce_country_language_from_url(url: str) -> tuple[str, str]:
    if "br.investing.com" in url:
        return ("BR", "pt-BR")
    return ("", "")

def make_news_id(url: str, title: str) -> str:
    base = (url or "").strip() + "||" + (title or "").strip()
    return str(uuid.uuid5(uuid.NAMESPACE_URL, base))

def html_debug_dump(html: str, company: str, page: int, outdir: Path) -> None:
    outdir.mkdir(parents=True, exist_ok=True)
    fn = outdir / f"{safe_filename(company)}_p{page:04d}.html"
    try:
        fn.write_text(html, encoding="utf-8")
        log.debug(f"HTML salvo para debug: {fn}")
    except Exception as e:
        log.warning(f"Falha ao salvar HTML de debug: {e}")

def safe_filename(s: str) -> str:
    return re.sub(r"[^A-Za-z0-9._-]+", "_", s.strip())

# ---------------- HTTP com backoff ----------------
def fetch(url: str, max_retries: int = 5, timeout: int = 25) -> Optional[requests.Response]:
    for i in range(max_retries):
        try:
            r = SESSION.get(url, timeout=timeout)
            if r.status_code == 200:
                return r
            if r.status_code in (404, 410):
                log.info(f"HTTP {r.status_code} em {url} (provável fim).")
                return None
            if r.status_code in (429, 500, 502, 503, 504):
                wait = (1.5 * (i + 1)) + random.random()
                log.warning(f"HTTP {r.status_code} em {url}; retry em {wait:.1f}s")
                time.sleep(wait)
                continue
            log.warning(f"HTTP {r.status_code} em {url}; sem retry programado.")
            return None
        except requests.RequestException as e:
            wait = (1.2 * (i + 1)) + random.random()
            log.warning(f"Erro rede: {e}; retry em {wait:.1f}s")
            time.sleep(wait)
    log.error(f"Falhou após {max_retries} tentativas: {url}")
    return None

# ---------------- Parsing ----------------
def parse_news_items(html: str, ticker: str, sector: str) -> List[Dict]:
    soup = BeautifulSoup(html, "html.parser")
    ul = soup.find("ul", attrs={"data-test": "news-list"})
    if not ul:
        log.debug("Ul[data-test='news-list'] não encontrada — página pode ter mudado.")
        return []

    items: List[Dict] = []
    arts = ul.select("article[data-test='article-item']")
    if not arts:
        log.debug("Nenhum article[data-test='article-item'] encontrado nesta página.")
        return []

    for art in arts:
        a_title = art.select_one("a[data-test='article-title-link']")
        if not a_title:
            log.debug("a[data-test='article-title-link'] ausente em um article; pulando.")
            continue

        headline = (a_title.get_text() or "").strip()
        url = a_title.get("href") or ""
        if url.startswith("/"):
            url = "https://br.investing.com" + url

        a_provider = art.select_one("a[data-test='article-provider-link']")
        source = (a_provider.get_text().strip() if a_provider else "").strip()

        t = art.select_one("time[data-test='article-publish-date']")
        dt = parse_datetime_from_time_tag(t)

        country, language = deduce_country_language_from_url(url)
        _id = make_news_id(url, headline)

        items.append(
            {
                "id": _id,
                "datetime": dt.isoformat() if dt else None,
                "source": source,
                "headline": headline,
                "ticker": ticker,
                "sector": sector,
                "country": country,
                "url": url,
                "language": language,
            }
        )
    return items

def guess_last_page(html: str) -> Optional[int]:
    soup = BeautifulSoup(html, "html.parser")
    pag_links = soup.select("div.flex.items-center.gap-2 a")
    nums = []
    for a in pag_links:
        txt = (a.get_text() or "").strip()
        if txt.isdigit():
            nums.append(int(txt))
    return max(nums) if nums else None

# ---------------- Scraper por empresa ----------------
def scrape_company(
    link_news: str,
    ticker_orig: str,
    sector: str,
    company_label: str,
    polite_sleep: float = 0.7,
    max_pages: Optional[int] = DEFAULT_MAX_PAGES,
    save_html_debug: bool = False,
    html_debug_dir: Path = Path("./_html_debug"),
) -> List[Dict]:
    url_base = normalize_news_url(link_news)
    if not url_base:
        log.warning(f"[{company_label}] Link News vazio.")
        return []

    first_url = page_url(url_base, 1)
    r1 = fetch(first_url)
    if not r1:
        log.warning(f"[{company_label}] Não foi possível carregar a página 1: {first_url}")
        return []

    if save_html_debug:
        html_debug_dump(r1.text, company_label, 1, html_debug_dir)

    items = parse_news_items(r1.text, ticker_orig, sector)
    log.info(f"[{company_label}] p1: {len(items)} items.")

    last_page = guess_last_page(r1.text)
    if last_page is None:
        # fallback: iterar enquanto vier notícia (parando após X vazias seguidas)
        page = 2
        empty_streak = 0
        while True:
            if max_pages and page > max_pages:
                log.info(f"[{company_label}] max_pages atingido ({max_pages}).")
                break

            url = page_url(url_base, page)
            time.sleep(polite_sleep)
            r = fetch(url)
            if not r:
                empty_streak += 1
                log.debug(f"[{company_label}] página {page} falhou ({empty_streak} vazias).")
                if empty_streak >= 3:
                    log.info(f"[{company_label}] 3 páginas vazias seguidas; encerrando.")
                    break
                page += 1
                continue

            if save_html_debug:
                html_debug_dump(r.text, company_label, page, html_debug_dir)

            chunk = parse_news_items(r.text, ticker_orig, sector)
            log.info(f"[{company_label}] p{page}: {len(chunk)} items.")
            if not chunk:
                empty_streak += 1
                if empty_streak >= 3:
                    log.info(f"[{company_label}] 3 páginas sem itens; encerrando.")
                    break
            else:
                items.extend(chunk)
                empty_streak = 0
            page += 1
    else:
        total_pages = last_page
        if max_pages:
            total_pages = min(total_pages, max_pages)
        for page in range(2, total_pages + 1):
            url = page_url(url_base, page)
            time.sleep(polite_sleep)
            r = fetch(url)
            if not r:
                log.debug(f"[{company_label}] Falha ao carregar p{page}.")
                continue

            if save_html_debug:
                html_debug_dump(r.text, company_label, page, html_debug_dir)

            chunk = parse_news_items(r.text, ticker_orig, sector)
            log.info(f"[{company_label}] p{page}: {len(chunk)} items.")
            items.extend(chunk)

    return items

# ---------------- Execução principal ----------------
def read_excel(excel_path: Path) -> pd.DataFrame:
    df = pd.read_excel(excel_path)
    # ATUALIZADO: Verifica as colunas do novo formato para ativos nacionais
    expected_cols = {
        "Empresa", "Setor", "Ticker B3", "Ticker ADR", "Bolsa (EUA)", "Link News",
    }
    missing = expected_cols - set(df.columns)
    if missing:
        raise ValueError(f"Colunas faltantes no Excel: {sorted(missing)}")
    return df

def merge_incremental(df_new: pd.DataFrame, out_parquet: Path) -> pd.DataFrame:
    if out_parquet.exists():
        df_old = pd.read_parquet(out_parquet)
        df_all = pd.concat([df_old, df_new], ignore_index=True)
        df_all = df_all.drop_duplicates(subset=["id"]).reset_index(drop=True)
        return df_all
    return df_new

def sort_by_datetime(df: pd.DataFrame) -> pd.DataFrame:
    def _safe_parse_iso(x):
        try:
            return du.parse(x)
        except Exception:
            return None
    if "datetime" in df.columns:
        df["_dt_sort"] = df["datetime"].map(_safe_parse_iso)
        df = df.sort_values("_dt_sort", ascending=False).drop(columns=["_dt_sort"])
    return df

def run(
    excel: Path,
    out_parquet: Path,
    only: Optional[str],
    max_pages: Optional[int],
    save_html_debug: bool,
    workers: int,
):
    df_ref = read_excel(excel)
    if only:
        # ATUALIZADO: Filtra usando a coluna 'Ticker B3'
        mask = (
            df_ref["Ticker B3"].astype(str).str.contains(only, case=False, na=False) |
            df_ref["Empresa"].astype(str).str.contains(only, case=False, na=False)
        )
        df_ref = df_ref[mask].copy()
        log.info(f"Filtrando --only '{only}'. {len(df_ref)} linha(s) no Excel após filtro.")

    backup_dir = Path("./backup")
    backup_dir.mkdir(exist_ok=True)
    log.info(f"Diretório de backup individual: {backup_dir.resolve()}")

    for _, row in tqdm(df_ref.iterrows(), total=len(df_ref), desc="Empresas"):
        empresa = str(row["Empresa"]).strip()
        setor = str(row["Setor"]).strip()
        # ATUALIZADO: Pega o ticker da coluna 'Ticker B3'
        ticker_orig = str(row["Ticker B3"]).strip()
        link_news = str(row["Link News"]).strip()

        if not link_news or link_news.lower() == "nan":
            log.warning(f"[{empresa}] Link News vazio; pulando.")
            continue

        label = ticker_orig or empresa
        items = scrape_company(
            link_news=link_news,
            ticker_orig=ticker_orig or empresa,
            sector=setor,
            company_label=label,
            polite_sleep=0.7,
            max_pages=max_pages if max_pages is not None else DEFAULT_MAX_PAGES,
            save_html_debug=save_html_debug,
        )
        if not items:
            log.info(f"[{label}] Nenhuma notícia nova encontrada.")
            continue

        df_company = pd.DataFrame(items).drop_duplicates(subset=["id"]).reset_index(drop=True)

        backup_filename = f"{safe_filename(label)}.parquet"
        backup_filepath = backup_dir / backup_filename
        df_company.to_parquet(backup_filepath, index=False)
        log.info(f"[{label}] Backup individual com {len(df_company)} notícias salvo em: {backup_filepath}")

        df_merged = merge_incremental(df_company, out_parquet)
        df_merged = sort_by_datetime(df_merged)
        df_merged.to_parquet(out_parquet, index=False)
        log.info(f"[{label}] Salvo. O arquivo principal agora tem {len(df_merged):,} linhas em {out_parquet}")

    log.info("Processo concluído.")
    if not out_parquet.exists():
         log.warning("Nenhuma notícia foi coletada e o arquivo de saída não foi criado.")

# ---------------- CLI ----------------
def parse_args():
    p = argparse.ArgumentParser(description="Scraper de notícias do Investing.com (PT-BR)")
    p.add_argument("--excel", default=DEFAULT_EXCEL, help="Caminho do Excel de referência")
    p.add_argument("--out", default=DEFAULT_OUT, help="Arquivo Parquet de saída")
    # ATUALIZADO: Ajuda reflete a mudança para Ticker B3
    p.add_argument("--only", default=None, help="Filtra por Ticker B3 ou Empresa")
    p.add_argument("--max-pages", type=int, default=DEFAULT_MAX_PAGES, help="Limite máx. de páginas por ativo")
    p.add_argument("--save-html-debug", action="store_true", help="Salva HTML das páginas em ./_html_debug")
    p.add_argument("--workers", type=int, default=1, help="(reservado) Nº de workers em paralelo")
    p.add_argument("--verbose", action="store_true", help="Logs detalhados (DEBUG)")
    p.add_argument("--debug", action="store_true", help="Equivalente a --verbose")
    args, _unknown = p.parse_known_args()
    return args

def main():
    import sys
    if any("ipykernel" in x for x in sys.argv):
        pass
    args = parse_args()
    setup_logging(verbose=args.verbose or args.debug, debug=args.debug)
    excel = Path(args.excel)
    out_parquet = Path(args.out)
    log.info(f"Excel: {excel.resolve()}")
    log.info(f"Saída: {out_parquet.resolve()}")
    if args.only:
        log.info(f"Filtro --only: {args.only}")
    log.info(f"Limite de páginas: {args.max_pages}")
    if args.save_html_debug:
        log.info("Salvar HTML debug: ON")
    try:
        run(
            excel=excel,
            out_parquet=out_parquet,
            only=args.only,
            max_pages=args.max_pages,
            save_html_debug=args.save_html_debug,
            workers=args.workers,
        )
    except Exception as e:
        log.exception(f"Falha fatal: {e}")

if __name__ == "__main__":
    main()
# Out:
# 17:40:11 | INFO    | Excel: /Users/emanuelgandra/Desktop/Projetos /TesteQuant/QuantumSpreadHunters---Quantamental/data/BaseRefAtivosNacionais.xlsx
# 17:40:11 | INFO    | Saída: /Users/emanuelgandra/Desktop/Projetos /TesteQuant/QuantumSpreadHunters---Quantamental/data/investing_news_nacionais_que_faltaram.parquet
# 17:40:11 | INFO    | Limite de páginas: 1400
# 17:40:11 | INFO    | Diretório de backup individual: /Users/emanuelgandra/Desktop/Projetos /TesteQuant/QuantumSpreadHunters---Quantamental/notebooks/backup
# Empresas:   0%|          | 0/7 [00:00<?, ?it/s]17:40:13 | INFO    | [SUZB3] p1: 10 items.
# 17:40:16 | INFO    | [SUZB3] p2: 10 items.
# 17:40:18 | INFO    | [SUZB3] p3: 10 items.
# 17:40:20 | INFO    | [SUZB3] p4: 10 items.
# 17:40:22 | INFO    | [SUZB3] p5: 10 items.
# 17:40:24 | INFO    | [SUZB3] p6: 10 items.
# 17:40:26 | INFO    | [SUZB3] p7: 10 items.
# 17:40:28 | INFO    | [SUZB3] p8: 10 items.
# 17:40:30 | INFO    | [SUZB3] p9: 10 items.
# 17:40:32 | INFO    | [SUZB3] p10: 10 items.
# 17:40:34 | INFO    | [SUZB3] p11: 10 items.
# 17:40:36 | INFO    | [SUZB3] p12: 10 items.
# 17:40:38 | INFO    | [SUZB3] p13: 10 items.
# 17:40:40 | INFO    | [SUZB3] p14: 10 items.
# 17:40:42 | INFO    | [SUZB3] p15: 10 items.
# 17:40:43 | INFO    | [SUZB3] p16: 10 items.
# 17:40:46 | INFO    | [SUZB3] p17: 10 items.
# 17:47:08 | INFO    | [SUZB3] p223: 10 items.
# 17:47:10 | INFO    | [SUZB3] p224: 10 items.
# 17:47:12 | INFO    | [SUZB3] p225: 10 items.
# 17:47:14 | INFO    | [SUZB3] p226: 10 items.
# 17:47:16 | INFO    | [SUZB3] p227: 10 items.
# 17:47:17 | INFO    | [SUZB3] p228: 0 items.
# 17:47:19 | INFO    | [SUZB3] p229: 0 items.
# 17:47:21 | INFO    | [SUZB3] p230: 0 items.
# 17:47:24 | INFO    | [SUZB3] p231: 0 items.
# 17:47:26 | INFO    | [SUZB3] p232: 0 items.
# 17:47:28 | INFO    | [SUZB3] p233: 0 items.
# 17:47:30 | INFO    | [SUZB3] p234: 0 items.
# 17:47:32 | INFO    | [SUZB3] p235: 0 items.
# 17:47:34 | INFO    | [SUZB3] p236: 0 items.
# 17:47:36 | INFO    | [SUZB3] p237: 0 items.
# 17:47:38 | INFO    | [SUZB3] p238: 0 items.
# 17:47:40 | INFO    | [SUZB3] p239: 0 items.
# 17:47:42 | INFO    | [SUZB3] p240: 0 items.
# 17:47:43 | INFO    | [SUZB3] p241: 0 items.
# 17:47:45 | INFO    | [SUZB3] p242: 0 items.
# 17:47:47 | INFO    | [SUZB3] p243: 0 items.
# 17:47:49 | INFO    | [SUZB3] p244: 0 items.
# 17:47:51 | INFO    | [SUZB3] p245: 0 items.
# 17:47:53 | INFO    | [SUZB3] p246: 0 items.
# 17:47:55 | INFO    | [SUZB3] p247: 0 items.
# 17:47:57 | INFO    | [SUZB3] p248: 0 items.
# 17:47:59 | INFO    | [SUZB3] p249: 0 items.
# 17:48:00 | INFO    | [SUZB3] p250: 0 items.
# 17:48:01 | INFO    | [SUZB3] Backup individual com 2254 notícias salvo em: backup/SUZB3.parquet
# 17:48:01 | INFO    | [SUZB3] Salvo. O arquivo principal agora tem 2,254 linhas em ../data/investing_news_nacionais_que_faltaram.parquet
# Empresas:  14%|█▍        | 1/7 [07:49<46:59, 469.90s/it]17:48:01 | INFO    | HTTP 404 em https://br.investing.com/equities/sabesp-on/1 (provável fim).
# 17:48:01 | WARNING | [SBSP3] Não foi possível carregar a página 1: https://br.investing.com/equities/sabesp-on/1
# 17:48:01 | INFO    | [SBSP3] Nenhuma notícia nova encontrada.
# Empresas:  29%|██▊       | 2/7 [07:50<16:10, 194.00s/it]17:48:04 | INFO    | [ELET3 / ELET6] p1: 10 items.
# 17:48:06 | INFO    | [ELET3 / ELET6] p2: 10 items.
# 17:48:07 | INFO    | [ELET3 / ELET6] p3: 10 items.
# 17:48:09 | INFO    | [ELET3 / ELET6] p4: 10 items.
# 17:48:11 | INFO    | [ELET3 / ELET6] p5: 10 items.
# 17:48:13 | INFO    | [ELET3 / ELET6] p6: 10 items.
# 17:48:15 | INFO    | [ELET3 / ELET6] p7: 10 items.
# 17:48:17 | INFO    | [ELET3 / ELET6] p8: 10 items.
# 17:48:18 | INFO    | [ELET3 / ELET6] p9: 10 items.
# 17:48:20 | INFO    | [ELET3 / ELET6] p10: 10 items.
# 17:48:24 | INFO    | [ELET3 / ELET6] p11: 10 items.
# 17:51:33 | INFO    | [ELET3 / ELET6] p100: 10 items.
# 17:51:35 | INFO    | [ELET3 / ELET6] p101: 10 items.
# 17:51:36 | INFO    | [ELET3 / ELET6] p102: 10 items.
# 17:51:39 | INFO    | [ELET3 / ELET6] p103: 10 items.
# 17:51:40 | INFO    | [ELET3 / ELET6] p104: 10 items.
# 17:51:42 | INFO    | [ELET3 / ELET6] p105: 10 items.
# 17:51:44 | INFO    | [ELET3 / ELET6] p106: 10 items.
# 17:51:46 | INFO    | [ELET3 / ELET6] p107: 10 items.
# 17:51:48 | INFO    | [ELET3 / ELET6] p108: 10 items.
# 17:51:50 | INFO    | [ELET3 / ELET6] p109: 10 items.
# 17:51:52 | INFO    | [ELET3 / ELET6] p110: 10 items.
# 17:51:55 | INFO    | [ELET3 / ELET6] p111: 10 items.
# 17:51:57 | INFO    | [ELET3 / ELET6] p112: 10 items.
# 17:51:58 | INFO    | [ELET3 / ELET6] p113: 10 items.
# 17:52:00 | INFO    | [ELET3 / ELET6] p114: 10 items.
# 17:52:02 | INFO    | [ELET3 / ELET6] p115: 10 items.
# 17:52:04 | INFO    | [ELET3 / ELET6] p116: 10 items.
# 17:52:06 | INFO    | [ELET3 / ELET6] p117: 10 items.
# 17:52:08 | INFO    | [ELET3 / ELET6] p118: 10 items.
# 17:52:09 | INFO    | [ELET3 / ELET6] p119: 10 items.
# 17:52:11 | INFO    | [ELET3 / ELET6] p120: 10 items.
# 17:52:13 | INFO    | [ELET3 / ELET6] p121: 10 items.
# 17:52:15 | INFO    | [ELET3 / ELET6] p122: 10 items.
# 17:52:17 | INFO    | [ELET3 / ELET6] p123: 10 items.
# 17:52:19 | INFO    | [ELET3 / ELET6] p124: 10 items.
# 17:52:21 | INFO    | [ELET3 / ELET6] p125: 10 items.
# 17:52:22 | INFO    | [ELET3 / ELET6] p126: 10 items.
# 17:52:25 | INFO    | [ELET3 / ELET6] p127: 10 items.
# 17:52:27 | INFO    | [ELET3 / ELET6] p128: 10 items.
# 17:52:29 | INFO    | [ELET3 / ELET6] p129: 10 items.
# 17:52:33 | INFO    | [ELET3 / ELET6] p130: 10 items.
# 17:52:35 | INFO    | [ELET3 / ELET6] p131: 10 items.
# 17:52:38 | INFO    | [ELET3 / ELET6] p132: 10 items.
# 17:52:41 | INFO    | [ELET3 / ELET6] p133: 10 items.
# 17:52:42 | INFO    | [ELET3 / ELET6] p134: 10 items.
# 17:52:44 | INFO    | [ELET3 / ELET6] p135: 10 items.
# 17:52:47 | INFO    | [ELET3 / ELET6] p136: 10 items.
# 17:52:49 | INFO    | [ELET3 / ELET6] p137: 10 items.
# 17:52:51 | INFO    | [ELET3 / ELET6] p138: 10 items.
# 17:52:53 | INFO    | [ELET3 / ELET6] p139: 10 items.
# 17:52:55 | INFO    | [ELET3 / ELET6] p140: 10 items.
# 17:52:57 | INFO    | [ELET3 / ELET6] p141: 10 items.
# 17:52:59 | INFO    | [ELET3 / ELET6] p142: 10 items.
# 17:53:01 | INFO    | [ELET3 / ELET6] p143: 10 items.
# 17:53:03 | INFO    | [ELET3 / ELET6] p144: 10 items.
# 17:53:05 | INFO    | [ELET3 / ELET6] p145: 10 items.
# 17:53:06 | INFO    | [ELET3 / ELET6] p146: 10 items.
# 17:53:08 | INFO    | [ELET3 / ELET6] p147: 10 items.
# 17:53:10 | INFO    | [ELET3 / ELET6] p148: 10 items.
# 17:53:12 | INFO    | [ELET3 / ELET6] p149: 10 items.
# 17:53:13 | INFO    | [ELET3 / ELET6] p150: 10 items.
# 17:53:15 | INFO    | [ELET3 / ELET6] p151: 10 items.
# 17:53:17 | INFO    | [ELET3 / ELET6] p152: 3 items.
# 17:53:19 | INFO    | [ELET3 / ELET6] p153: 10 items.
# 17:53:21 | INFO    | [ELET3 / ELET6] p154: 10 items.
# 17:53:22 | INFO    | [ELET3 / ELET6] p155: 10 items.
# 17:53:24 | INFO    | [ELET3 / ELET6] p156: 10 items.
# 17:53:26 | INFO    | [ELET3 / ELET6] p157: 10 items.
# 17:53:28 | INFO    | [ELET3 / ELET6] p158: 10 items.
# 17:53:30 | INFO    | [ELET3 / ELET6] p159: 10 items.
# 17:53:32 | INFO    | [ELET3 / ELET6] p160: 10 items.
# 17:53:34 | INFO    | [ELET3 / ELET6] p161: 10 items.
# 17:53:35 | INFO    | [ELET3 / ELET6] p162: 10 items.
# 17:53:37 | INFO    | [ELET3 / ELET6] p163: 10 items.
# 17:53:39 | INFO    | [ELET3 / ELET6] p164: 10 items.
# 17:53:41 | INFO    | [ELET3 / ELET6] p165: 10 items.
# 17:53:43 | INFO    | [ELET3 / ELET6] p166: 10 items.
# 17:53:45 | INFO    | [ELET3 / ELET6] p167: 10 items.
# 17:53:47 | INFO    | [ELET3 / ELET6] p168: 10 items.
# 17:53:49 | INFO    | [ELET3 / ELET6] p169: 10 items.
# 17:53:50 | INFO    | [ELET3 / ELET6] p170: 10 items.
# 17:53:52 | INFO    | [ELET3 / ELET6] p171: 10 items.
# 17:53:54 | INFO    | [ELET3 / ELET6] p172: 10 items.
# 17:53:56 | INFO    | [ELET3 / ELET6] p173: 10 items.
# 17:53:58 | INFO    | [ELET3 / ELET6] p174: 10 items.
# 17:54:00 | INFO    | [ELET3 / ELET6] p175: 10 items.
# 17:54:02 | INFO    | [ELET3 / ELET6] p176: 10 items.
# 17:54:04 | INFO    | [ELET3 / ELET6] p177: 10 items.
# 17:54:05 | INFO    | [ELET3 / ELET6] p178: 10 items.
# 17:54:07 | INFO    | [ELET3 / ELET6] p179: 10 items.
# 17:54:09 | INFO    | [ELET3 / ELET6] p180: 10 items.
# 17:54:11 | INFO    | [ELET3 / ELET6] p181: 10 items.
# 17:54:13 | INFO    | [ELET3 / ELET6] p182: 10 items.
# 17:54:17 | INFO    | [ELET3 / ELET6] p183: 10 items.
# 17:54:18 | INFO    | [ELET3 / ELET6] p184: 10 items.
# 17:54:20 | INFO    | [ELET3 / ELET6] p185: 10 items.
# 17:54:22 | INFO    | [ELET3 / ELET6] p186: 10 items.
# 17:54:24 | INFO    | [ELET3 / ELET6] p187: 10 items.
# 17:54:26 | INFO    | [ELET3 / ELET6] p188: 10 items.
# 17:54:28 | INFO    | [ELET3 / ELET6] p189: 10 items.
# 17:54:30 | INFO    | [ELET3 / ELET6] p190: 10 items.
# 17:54:32 | INFO    | [ELET3 / ELET6] p191: 10 items.
# 17:54:34 | INFO    | [ELET3 / ELET6] p192: 10 items.
# 17:54:36 | INFO    | [ELET3 / ELET6] p193: 10 items.
# 17:54:37 | INFO    | [ELET3 / ELET6] p194: 10 items.
# 17:54:39 | INFO    | [ELET3 / ELET6] p195: 10 items.
# 17:54:41 | INFO    | [ELET3 / ELET6] p196: 10 items.
# 17:54:45 | INFO    | [ELET3 / ELET6] p197: 10 items.
# 17:54:47 | INFO    | [ELET3 / ELET6] p198: 10 items.
# 17:54:49 | INFO    | [ELET3 / ELET6] p199: 10 items.
# 17:54:51 | INFO    | [ELET3 / ELET6] p200: 10 items.
# 17:54:53 | INFO    | [ELET3 / ELET6] p201: 10 items.
# 17:54:54 | INFO    | [ELET3 / ELET6] p202: 10 items.
# 17:54:56 | INFO    | [ELET3 / ELET6] p203: 10 items.
# 17:54:58 | INFO    | [ELET3 / ELET6] p204: 10 items.
# 17:55:00 | INFO    | [ELET3 / ELET6] p205: 10 items.
# 17:55:01 | INFO    | [ELET3 / ELET6] p206: 10 items.
# 17:55:03 | INFO    | [ELET3 / ELET6] p207: 10 items.
# 17:55:05 | INFO    | [ELET3 / ELET6] p208: 10 items.
# 17:55:07 | INFO    | [ELET3 / ELET6] p209: 10 items.
# 17:55:09 | INFO    | [ELET3 / ELET6] p210: 10 items.
# 17:55:11 | INFO    | [ELET3 / ELET6] p211: 10 items.
# 17:55:13 | INFO    | [ELET3 / ELET6] p212: 10 items.
# 17:55:15 | INFO    | [ELET3 / ELET6] p213: 10 items.
# 17:55:17 | INFO    | [ELET3 / ELET6] p214: 10 items.
# 17:55:18 | INFO    | [ELET3 / ELET6] p215: 10 items.
# 17:55:21 | INFO    | [ELET3 / ELET6] p216: 10 items.
# 17:55:23 | INFO    | [ELET3 / ELET6] p217: 10 items.
# 17:55:25 | INFO    | [ELET3 / ELET6] p218: 10 items.
# 17:55:27 | INFO    | [ELET3 / ELET6] p219: 5 items.
# 17:55:29 | INFO    | [ELET3 / ELET6] p220: 10 items.
# 17:55:30 | INFO    | [ELET3 / ELET6] p221: 10 items.
# 17:55:32 | INFO    | [ELET3 / ELET6] p222: 10 items.
# 17:55:34 | INFO    | [ELET3 / ELET6] p223: 10 items.
# 17:55:36 | INFO    | [ELET3 / ELET6] p224: 10 items.
# 17:55:39 | INFO    | [ELET3 / ELET6] p225: 10 items.
# 17:55:40 | INFO    | [ELET3 / ELET6] p226: 10 items.
# 17:55:42 | INFO    | [ELET3 / ELET6] p227: 10 items.
# 17:55:44 | INFO    | [ELET3 / ELET6] p228: 10 items.
# 17:55:46 | INFO    | [ELET3 / ELET6] p229: 10 items.
# 17:55:47 | INFO    | [ELET3 / ELET6] p230: 10 items.
# 17:55:49 | INFO    | [ELET3 / ELET6] p231: 6 items.
# 59086  cc9d69b3-e437-594c-ad87-d8c91b34cc3e         1970-01-01T00:00:01-03:00
# 59087  23da46c0-b217-5de2-81e8-937faa164244         1970-01-01T00:00:01-03:00
#
#                 source                                           headline  \
# 0        Investing.com  CFO da Apple vende ações no valor de US$ 1 milhão
# 1              Reuters  Petrobras amplia vendas de petróleo para Índia...
# 2              Reuters           João Fukunaga deixa presidência da Previ
# 3              Reuters  Ibovespa sobe e flerta com 143 mil pontos; Pri...
# 4        Investing.com  Apple garante direitos exclusivos de streaming...
# ...                ...                                                ...
# 59083    Investing.com  Bolsas dos EUA abrem em alta após relatório im...
# 59084    Investing.com  Bolsas dos EUA sobem antes de dados; Dow Jones...
# 59085      Money Times  Itaú BBA eleva em 38,5% o preço-alvo para Maga...
# 59086          Reuters  Fraqueza em Wall Street dita queda do Ibovespa...
# 59087  Arena do Pavini  As ações mais indicadas pelos analistas em jul...
#
#               ticker      sector country  \
# 0              VALE3   Mineração      BR
# 1      PETR3 / PETR4  Óleo e Gás      BR
# 2      BBDC3 / BBDC4  Financeiro      BR
# 3              VALE3   Mineração      BR
# 4              VALE3   Mineração      BR
# ...              ...         ...     ...
# 59083          VALE3   Mineração      BR
# 59084          VALE3   Mineração      BR
# 59085  ITUB3 / ITUB4  Financeiro      BR
# 59086  ITUB3 / ITUB4  Financeiro      BR
# 59087  ITUB3 / ITUB4  Financeiro      BR
#
#                                                      url language
# 0      https://br.investing.com/news/insider-trading-...    pt-BR
# 1      https://br.investing.com/news/commodities-news...    pt-BR
# 2      https://br.investing.com/news/stock-market-new...    pt-BR
# 3      https://br.investing.com/news/stock-market-new...    pt-BR
# 4      https://br.investing.com/news/stock-market-new...    pt-BR
# ...                                                  ...      ...
# 59083  https://br.investing.com/news/stock-market-new...    pt-BR
# 59084  https://br.investing.com/news/stock-market-new...    pt-BR
# 59085  https://br.investing.com/news/stock-market-new...    pt-BR
# 59086  https://br.investing.com/news/stock-market-new...    pt-BR
# 59087  https://br.investing.com/news/stock-market-new...    pt-BR
#
# [59088 rows x 9 columns]

# %%
#Agrupar por 'ticker'
agrupado = dados.groupby('ticker').size().reset_index(name='contagem')
agrupado
# Out:
#            ticker  contagem
# 0           ABEV3       722
# 1           AZUL4      1389
# 2           B3SA3      6050
# 3   BBDC3 / BBDC4      2961
# 4           BRFS3      1427
# 5   CMIG3 / CMIG4      1400
# 6           CSAN3       613
# 7           CSNA3      1010
# 8           EMBR3      2216
# 9   GGBR3 / GGBR4      1219
# 10          GOLL4       969
# 11  ITUB3 / ITUB4      3890
# 12          JBSS3      2127
# 13          LREN3       436
# 14          MGLU3       937
# 15          MRFG3       462
# 16         PAGS31       141
# 17  PETR3 / PETR4      7141
# 18         ROXO34       386
# 19         SANB11      2433
# 20         STOC31       382
# 21          TIMS3      1599
# 22          UGPA3       421
# 23          VALE3     17588
# 24          VIVT3       416
# 25          WEGE3       407
# 26         XPBR31       346

# %%
#Pegar as 10 primeiras linhas
sample = dados.head(10)
sample.to_csv("sample_bdrs.csv", index=False)
